# %%
# %%capture
import tensorflow as tf
from tensorflow import keras
from scipy.io import loadmat
from tensorflow.keras import regularizers
import os
import time
import numpy as np
import gc
import shutil
from tensorflow.keras.models import model_from_json
from tqdm import tqdm_notebook
import matplotlib.pyplot as plt
from tensorflow.keras import backend as K
from sklearn.metrics import r2_score
from sklearn import preprocessing

# %%
def scale(x):
    """
    Scales the input data by subtracting the mean and dividing by the standard deviation 
    
    Inputs: x: a n-dimensional tensor
    
    Returns: a n-dimensional tensor of same shape as x
    """

    return (x - np.mean(x)) / np.std(x)

# %%
def preprocess(x):
    """
    Cuts the input 75% along the z-axis to remove laminar layers
    
    Inputs: x: a 3-dimensional tensor
    
    Returns: a 3-dimensional tensor of shape (length, width, 56)
    """
    
    return x[:,:,:int(0.75*x.shape[2])]

# %%
path = os.getcwd()
path
# Out:
# '/home/llin2948/dscaptstone'

# %%
# Create directories to save independent and dependent variables
if not os.path.exists(path + "/Train_Data"):
    os.mkdir(path + "/Train_Data")
    os.mkdir(path + "/Train_Data/Data")
    os.mkdir(path + "/Train_Data/Labels")
    os.mkdir(path + "/Train_Data/Labels/Tau_23")
    os.mkdir(path + "/Train_Data/Labels/Tau_12")
    os.mkdir(path + "/Train_Data/Labels/Tau_13")
else:
    shutil.rmtree(path + "/Train_Data")
    os.mkdir(path + "/Train_Data")
    os.mkdir(path + "/Train_Data/Data")
    os.mkdir(path + "/Train_Data/Labels")
    os.mkdir(path + "/Train_Data/Labels/Tau_23")
    os.mkdir(path + "/Train_Data/Labels/Tau_12")
    os.mkdir(path + "/Train_Data/Labels/Tau_13")
    
if not os.path.exists(path + "/Saved_Models_2Sets"):
    os.mkdir(path + "/Saved_Models_2Sets")

# %% [markdown]
# # 1. Generae Input datasets

# %%
counter = 1
size = 3
ini = 0
name = ['_DNS8.mat']
subdirs = ["Re15sh2_DNScoarse8","Re15sh20_DNScoarse8"]
for directory in subdirs:
    os.chdir(path + "/Data/" + directory)
    print("Reading: " + directory)
    
    # Load data and check its shape
    uname = 'u_F_xyz_T1'+name[ini]
    vname = 'v_F_xyz_T1'+name[ini]
    wname = 'w_F_xyz_T1'+name[ini]
    tau1na = 'tau12_F_xyz_T1'+name[ini]
    tau2na = 'tau13_F_xyz_T1'+name[ini]
    tau3na = 'tau23_F_xyz_T1'+name[ini]
    u = preprocess(scale(loadmat(uname)["u_F"]))
    v = preprocess(scale(loadmat(vname)["v_F"]))
    w = preprocess(scale(loadmat(wname)["w_F"]))
    tau_12 = preprocess(scale(loadmat(tau1na)["tau12"]))
    tau_13 = preprocess(scale(loadmat(tau2na)["tau13"]))
    tau_23 = preprocess(scale(loadmat(tau3na)["tau23"]))
    print("Data Shape: " + str(u.shape))
    
    x = np.array([u, v, w])
    x = np.transpose(x, [1, 2, 3, 0])
    x = np.pad(x, ((size,size), (size,size), (size,size), (0,0)), 'constant', constant_values = 0)
    del u
    del v
    del w
    gc.collect()
    
    # Create and save randomized dataset shards to disk
    sample = []
    y_tau_23 = []
    y_tau_12 = []
    y_tau_13 = []
    num_files = 10

    x_range = np.arange(size, x.shape[0] - size)
    np.random.shuffle(x_range)
    y_range = np.arange(size, x.shape[1] - size)
    np.random.shuffle(y_range)
    z_range = np.arange(size, x.shape[2] - size)
    np.random.shuffle(z_range)
    for i in x_range:
        for j in y_range:
            for k in z_range:
                sample.append(x[i - size: i + size + 1, j - size: j + size + 1, k - size: k + size + 1, :])
                y_tau_23.append(tau_23[i - size][j - size][k - size])
                y_tau_12.append(tau_12[i - size][j - size][k - size])
                y_tau_13.append(tau_13[i - size][j - size][k - size])

                if len(sample) == int(((x.shape[0] - size * 2) * (x.shape[1] - size * 2) * (x.shape[2] - size * 2)) / num_files):
                    os.chdir(path + "/Train_Data/Data")
                    np.save(str(counter), np.array(sample))
                    os.chdir(path + "/Train_Data/Labels/Tau_23")
                    np.save(str(counter), np.array(y_tau_23))
                    os.chdir(path + "/Train_Data/Labels/Tau_12")
                    np.save(str(counter), np.array(y_tau_12))
                    os.chdir(path + "/Train_Data/Labels/Tau_13")
                    np.save(str(counter), np.array(y_tau_13))

                    del sample
                    del y_tau_13
                    del y_tau_12
                    del y_tau_23
                    gc.collect()
                    sample = []
                    y_tau_23 = []
                    y_tau_12 = []
                    y_tau_13 = []
                    
                    counter += 1
    del x
    del tau_12
    del tau_13
    del tau_23
    gc.collect()
    print("Saved " + directory + " to disk\n")
# Out:
# Reading: Re15sh20_DNScoarse8
# Data Shape: (146, 96, 56)
# Saved Re15sh20_DNScoarse8 to disk
#
# Reading: Re15sh2_DNScoarse8
# Data Shape: (146, 96, 54)
# Saved Re15sh2_DNScoarse8 to disk

# %% [markdown]
# # 2. Build Model

# %%
class DNN(object):
    
    def __init__(self, activation, initializer, regularizer, input_shape):
        self.activation = activation
        self.initializer = initializer
        self.regularizer = regularizer
        self.input_shape = input_shape
        
        pass 
    
    def create_model(self):
        """
        Creates sequential keras model

        Inputs: self

        Returns: a sequential keras model with the parameters defined in __init__
        """
        
        model = keras.Sequential([
            tf.keras.layers.Flatten(input_shape = self.input_shape),
            tf.keras.layers.Dense(128, 
                             activation = self.activation, 
                             kernel_regularizer = self.regularizer, 
                             kernel_initializer = self.initializer),
            tf.keras.layers.Dropout(0.2),
            tf.keras.layers.Dense(64, 
                             activation = self.activation, 
                             kernel_regularizer = self.regularizer, 
                             kernel_initializer = self.initializer),
            tf.keras.layers.Dropout(0.2),
            tf.keras.layers.Dense(32, 
                             activation = self.activation, 
                             kernel_regularizer = self.regularizer, 
                             kernel_initializer = self.initializer),
            tf.keras.layers.Dense(1)
        ])
        return model

# %% [markdown]
# # 3. Run model

# %%
# %%time
# Define model parameters
activation = tf.nn.relu
initializer = None
regularizer = None
epochs = 50
batch_size = 1000
val_split = 0.2
size = 3
num_files = 10

datasets = ["Tau_12", "Tau_13", "Tau_23"]
results = {}
i = 1
k = 1
os.chdir(path+"/Saved_Models_2Sets")
print("Box size used: " + str((2 * size + 1, 2 * size + 1, 2 * size + 1, 3)))
fig = plt.figure(figsize = (20, 6))
for name in datasets:
    x_test = []
    y_test = []
    print("\nPredicting " + name)
    input_shape = (2 * size + 1, 2 * size + 1, 2 * size + 1, 3)
    neural_net = DNN(activation, initializer, regularizer, input_shape)
    model = neural_net.create_model()
    model.compile(optimizer = tf.train.AdamOptimizer(), loss = "mse")
    correlation = []
    R2 = []
    for i in range(epochs):
        temp_1 = []
        temp_2 = []        
        files_range = np.arange(1, num_files * 2 + 1)
        np.random.shuffle(files_range)
        for j in files_range:
            
            # Load shards
            print("\nRunning Dataset:" + name + ": Epoch: " + str(i) + ": fileSet: " + str(j)) 
            x = np.load(path + "/Train_Data/Data/" + str(j) + ".npy")
            y = np.load(path + "/Train_Data/Labels/" + name + "/" + str(j) + ".npy")
            
            # Create train and test sets
            mask =  np.random.rand(x.shape[0]) < 0.80
            x_train = x[mask,:,:,:,:]
            y_train = y[mask]
            x_test = x[~mask,:,:,:,:]
            y_test = y[~mask]
            del y
            del mask
            gc.collect()
            
            # Fit model
            model.fit(x_train, y_train, epochs = 1, validation_split = 0.2, batch_size = batch_size, verbose = 1)
            del x_train
            del y_train
            gc.collect()
            
            # Get test corr and R2 for shard
            y_pred = model.predict(x_test).flatten()
            gc.collect()
            y_true = y_test.flatten()
            temp_1.append(r2_score(y_true, y_pred))
            temp_2.append(np.corrcoef(y_pred, y_true)[0, 1])
            del x_test
            del y_test
            del x
            gc.collect()
            #i += 1
        
        # Get average test corr and R2 for the epoch
        correlation.append(np.mean(temp_2))
        R2.append(np.mean(temp_1))
    
    # Save model to disk
    model_name_json = "model2_" + name + ".json"
    model_name_h5 = "model2_" + name + ".h5"
    model_json = model.to_json()
    with open(model_name_json, "w") as json_file:
        json_file.write(model_json)
    model.save_weights(model_name_h5)
    print("Saved model to disk\n")
    
    # Plot R2 and corr evolution
    fig.add_subplot(1, len(datasets), k)
    plt.plot(np.arange(1, epochs + 1), np.array(R2), label = 'R2')
    plt.plot(np.arange(1, epochs + 1), np.array(correlation), label = 'Correlation')
    plt.xlabel('Epoch')
    plt.legend()
    print("Final Dataset Correlation: %.4f" % np.corrcoef(y_pred, y_true)[0, 1])
    del y_pred
    del y_true
    gc.collect()
    
    k += 1
# Out:
# Box size used: (7, 7, 7, 3)
#
# Predicting Tau_12
#
# Running Dataset:Tau_12: Epoch: 0: fileSet: 3
# Train on 50236 samples, validate on 12560 samples
# Epoch 1/1
# 50236/50236 [==============================] - 3s 51us/step - loss: 1.5679 - val_loss: 0.9404
#
# Running Dataset:Tau_12: Epoch: 0: fileSet: 9
# Train on 50152 samples, validate on 12538 samples
# Epoch 1/1
# 50152/50152 [==============================] - 2s 31us/step - loss: 1.2164 - val_loss: 1.2300
#
# Running Dataset:Tau_12: Epoch: 0: fileSet: 6
# Train on 50290 samples, validate on 12573 samples
# Epoch 1/1
# 50290/50290 [==============================] - 2s 30us/step - loss: 1.2150 - val_loss: 1.2864
#
# Running Dataset:Tau_12: Epoch: 0: fileSet: 8
# Train on 50280 samples, validate on 12571 samples
# Epoch 1/1
# 50280/50280 [==============================] - 2s 30us/step - loss: 1.1042 - val_loss: 1.1579
#
# Running Dataset:Tau_12: Epoch: 0: fileSet: 16
# Train on 48594 samples, validate on 12149 samples
# Epoch 1/1
# 48594/48594 [==============================] - 1s 30us/step - loss: 1.1576 - val_loss: 1.1443
#
# Running Dataset:Tau_12: Epoch: 0: fileSet: 13
# Train on 48551 samples, validate on 12138 samples
# Epoch 1/1
# 48551/48551 [==============================] - 1s 30us/step - loss: 1.1599 - val_loss: 1.1076
#
# Running Dataset:Tau_12: Epoch: 0: fileSet: 12
# Train on 48452 samples, validate on 12113 samples
# Epoch 1/1
# 48452/48452 [==============================] - 1s 30us/step - loss: 1.0994 - val_loss: 1.0305
#
# Running Dataset:Tau_12: Epoch: 0: fileSet: 7
# Train on 50292 samples, validate on 12573 samples
# Epoch 1/1
# 50292/50292 [==============================] - 2s 30us/step - loss: 1.0107 - val_loss: 0.8629
#
# Running Dataset:Tau_12: Epoch: 0: fileSet: 19
# Train on 48416 samples, validate on 12104 samples
# Epoch 1/1
# 48416/48416 [==============================] - 1s 29us/step - loss: 1.1841 - val_loss: 1.0285
#
# Running Dataset:Tau_12: Epoch: 0: fileSet: 1
# Train on 50152 samples, validate on 12539 samples
# Epoch 1/1
# 50152/50152 [==============================] - 1s 30us/step - loss: 0.9095 - val_loss: 0.8507
#
# Running Dataset:Tau_12: Epoch: 0: fileSet: 15
# Train on 48476 samples, validate on 12120 samples
# Epoch 1/1
# 48476/48476 [==============================] - 1s 30us/step - loss: 0.9797 - val_loss: 0.9809
#
# Running Dataset:Tau_12: Epoch: 0: fileSet: 10
# Train on 50057 samples, validate on 12515 samples
# Epoch 1/1
# 50057/50057 [==============================] - 1s 30us/step - loss: 0.9328 - val_loss: 0.8232
#
# Running Dataset:Tau_12: Epoch: 0: fileSet: 18
# Train on 48397 samples, validate on 12100 samples
# Epoch 1/1
# 48397/48397 [==============================] - 1s 30us/step - loss: 1.0062 - val_loss: 0.9916
#
# Running Dataset:Tau_12: Epoch: 0: fileSet: 17
# Train on 48494 samples, validate on 12124 samples
# Epoch 1/1
# 48494/48494 [==============================] - 2s 31us/step - loss: 0.9948 - val_loss: 0.9889
#
# Running Dataset:Tau_12: Epoch: 0: fileSet: 20
# Train on 48420 samples, validate on 12105 samples
# Epoch 1/1
# 48420/48420 [==============================] - 1s 30us/step - loss: 0.9610 - val_loss: 0.9774
#
# Running Dataset:Tau_12: Epoch: 0: fileSet: 4
# Train on 50126 samples, validate on 12532 samples
# Epoch 1/1
# 50126/50126 [==============================] - 1s 30us/step - loss: 0.8619 - val_loss: 0.8963
#
# Running Dataset:Tau_12: Epoch: 0: fileSet: 14
# Train on 48335 samples, validate on 12084 samples
# Epoch 1/1
# 48335/48335 [==============================] - 1s 30us/step - loss: 0.9208 - val_loss: 0.8068
#
# Running Dataset:Tau_12: Epoch: 0: fileSet: 11
# Train on 48493 samples, validate on 12124 samples
# Epoch 1/1
# 48493/48493 [==============================] - 1s 30us/step - loss: 0.9320 - val_loss: 0.8964
#
# Running Dataset:Tau_12: Epoch: 0: fileSet: 5
# Train on 50529 samples, validate on 12633 samples
# Epoch 1/1
# 50529/50529 [==============================] - 1s 29us/step - loss: 0.8479 - val_loss: 0.8627
#
# Running Dataset:Tau_12: Epoch: 0: fileSet: 2
# Train on 50296 samples, validate on 12574 samples
# Epoch 1/1
# 50296/50296 [==============================] - 2s 30us/step - loss: 0.7494 - val_loss: 0.7010
#
# Running Dataset:Tau_12: Epoch: 1: fileSet: 11
# Train on 48502 samples, validate on 12126 samples
# Epoch 1/1
# 48502/48502 [==============================] - 1s 30us/step - loss: 0.8947 - val_loss: 0.9165
#
# Running Dataset:Tau_12: Epoch: 1: fileSet: 18
# Train on 48411 samples, validate on 12103 samples
# Epoch 1/1
# 48411/48411 [==============================] - 1s 30us/step - loss: 0.8779 - val_loss: 0.8796
#
# Running Dataset:Tau_12: Epoch: 1: fileSet: 15
# Train on 48388 samples, validate on 12097 samples
# Epoch 1/1
# 48388/48388 [==============================] - 1s 31us/step - loss: 0.8380 - val_loss: 0.8222
#
# Running Dataset:Tau_12: Epoch: 1: fileSet: 2
# Train on 50309 samples, validate on 12578 samples
# Epoch 1/1
# 50309/50309 [==============================] - 1s 29us/step - loss: 0.7087 - val_loss: 0.6603
#
# Running Dataset:Tau_12: Epoch: 1: fileSet: 12
# Train on 48319 samples, validate on 12080 samples
# Epoch 1/1
# 48319/48319 [==============================] - 1s 31us/step - loss: 0.8650 - val_loss: 0.8126
#
# Running Dataset:Tau_12: Epoch: 1: fileSet: 20
# Train on 48464 samples, validate on 12117 samples
# Epoch 1/1
# 48464/48464 [==============================] - 1s 30us/step - loss: 0.8618 - val_loss: 0.8518
#
# Running Dataset:Tau_12: Epoch: 1: fileSet: 16
# Train on 48531 samples, validate on 12133 samples
# Epoch 1/1
# 48531/48531 [==============================] - 1s 30us/step - loss: 0.8023 - val_loss: 0.8277
#
# Running Dataset:Tau_12: Epoch: 1: fileSet: 1
# Train on 50159 samples, validate on 12540 samples
# Epoch 1/1
# 50159/50159 [==============================] - 1s 30us/step - loss: 0.7306 - val_loss: 0.7428
#
# Running Dataset:Tau_12: Epoch: 1: fileSet: 6
# Train on 50220 samples, validate on 12555 samples
# Epoch 1/1
# 50220/50220 [==============================] - 1s 29us/step - loss: 0.7768 - val_loss: 0.8267
#
# Running Dataset:Tau_12: Epoch: 1: fileSet: 10
# Train on 50188 samples, validate on 12548 samples
# Epoch 1/1
# 50188/50188 [==============================] - 1s 29us/step - loss: 0.7486 - val_loss: 0.7068
#
# Running Dataset:Tau_12: Epoch: 1: fileSet: 5
# Train on 50307 samples, validate on 12577 samples
# Epoch 1/1
# 50307/50307 [==============================] - 1s 29us/step - loss: 0.7431 - val_loss: 0.7412
#
# Running Dataset:Tau_12: Epoch: 1: fileSet: 19
# Train on 48416 samples, validate on 12105 samples
# Epoch 1/1
# 48416/48416 [==============================] - 1s 30us/step - loss: 0.9452 - val_loss: 0.8098
#
# Running Dataset:Tau_12: Epoch: 1: fileSet: 17
# Train on 48264 samples, validate on 12067 samples
# Epoch 1/1
# 48264/48264 [==============================] - 1s 30us/step - loss: 0.8347 - val_loss: 0.8665
#
# Running Dataset:Tau_12: Epoch: 1: fileSet: 8
# Train on 50250 samples, validate on 12563 samples
# Epoch 1/1
# 50250/50250 [==============================] - 2s 30us/step - loss: 0.7681 - val_loss: 0.7539
#
# Running Dataset:Tau_12: Epoch: 1: fileSet: 14
# Train on 48468 samples, validate on 12118 samples
# Epoch 1/1
# 48468/48468 [==============================] - 1s 30us/step - loss: 0.8060 - val_loss: 0.7388
#
# Running Dataset:Tau_12: Epoch: 1: fileSet: 7
# Train on 50137 samples, validate on 12535 samples
# Epoch 1/1
# 50137/50137 [==============================] - 1s 29us/step - loss: 0.7902 - val_loss: 0.6839
#
# Running Dataset:Tau_12: Epoch: 1: fileSet: 4
# Train on 50151 samples, validate on 12538 samples
# Epoch 1/1
# 50151/50151 [==============================] - 2s 30us/step - loss: 0.7216 - val_loss: 0.8790
#
# Running Dataset:Tau_12: Epoch: 1: fileSet: 9
# Train on 50125 samples, validate on 12532 samples
# Epoch 1/1
# 50125/50125 [==============================] - 2s 30us/step - loss: 0.7020 - val_loss: 0.7057
#
# Running Dataset:Tau_12: Epoch: 1: fileSet: 13
# Train on 48457 samples, validate on 12115 samples
# Epoch 1/1
# 48457/48457 [==============================] - 1s 30us/step - loss: 0.8387 - val_loss: 0.7971
#
# Running Dataset:Tau_12: Epoch: 1: fileSet: 3
# Train on 50362 samples, validate on 12591 samples
# Epoch 1/1
# 50362/50362 [==============================] - 1s 30us/step - loss: 0.7357 - val_loss: 0.5381
#
# Running Dataset:Tau_12: Epoch: 2: fileSet: 7
# Train on 50201 samples, validate on 12551 samples
# Epoch 1/1
# 50201/50201 [==============================] - 1s 30us/step - loss: 0.7100 - val_loss: 0.6620
#
# Running Dataset:Tau_12: Epoch: 2: fileSet: 17
# Train on 48437 samples, validate on 12110 samples
# Epoch 1/1
# 48437/48437 [==============================] - 2s 35us/step - loss: 0.8269 - val_loss: 0.8245
#
# Running Dataset:Tau_12: Epoch: 2: fileSet: 5
# Train on 50180 samples, validate on 12545 samples
# Epoch 1/1
# 50180/50180 [==============================] - 2s 35us/step - loss: 0.7005 - val_loss: 0.6617
#
# Running Dataset:Tau_12: Epoch: 2: fileSet: 19
# Train on 48325 samples, validate on 12082 samples
# Epoch 1/1
# 48325/48325 [==============================] - 1s 29us/step - loss: 0.8933 - val_loss: 0.7920
#
# Running Dataset:Tau_12: Epoch: 2: fileSet: 4
# Train on 50208 samples, validate on 12553 samples
# Epoch 1/1
# 50208/50208 [==============================] - 1s 29us/step - loss: 0.6896 - val_loss: 0.8646
#
# Running Dataset:Tau_12: Epoch: 2: fileSet: 16
# Train on 48478 samples, validate on 12120 samples
# Epoch 1/1
# 48478/48478 [==============================] - 1s 29us/step - loss: 0.7545 - val_loss: 0.7557
#
# Running Dataset:Tau_12: Epoch: 2: fileSet: 12
# Train on 48472 samples, validate on 12119 samples
# Epoch 1/1
# 48472/48472 [==============================] - 1s 29us/step - loss: 0.7521 - val_loss: 0.7485
#
# Running Dataset:Tau_12: Epoch: 2: fileSet: 14
# Train on 48474 samples, validate on 12119 samples
# Epoch 1/1
# 48474/48474 [==============================] - 1s 30us/step - loss: 0.7291 - val_loss: 0.6704
#
# Running Dataset:Tau_12: Epoch: 2: fileSet: 3
# Train on 50223 samples, validate on 12556 samples
# Epoch 1/1
# 50223/50223 [==============================] - 1s 30us/step - loss: 0.6771 - val_loss: 0.5536
#
# Running Dataset:Tau_12: Epoch: 2: fileSet: 10
# Train on 50220 samples, validate on 12555 samples
# Epoch 1/1
# 50220/50220 [==============================] - 1s 30us/step - loss: 0.6836 - val_loss: 0.6377
#
# Running Dataset:Tau_12: Epoch: 2: fileSet: 13
# Train on 48456 samples, validate on 12114 samples
# Epoch 1/1
# 48456/48456 [==============================] - 1s 30us/step - loss: 0.7779 - val_loss: 0.7466
#
# Running Dataset:Tau_12: Epoch: 2: fileSet: 9
# Train on 50387 samples, validate on 12597 samples
# Epoch 1/1
# 50387/50387 [==============================] - 1s 29us/step - loss: 0.6713 - val_loss: 0.6993
#
# Running Dataset:Tau_12: Epoch: 2: fileSet: 11
# Train on 48387 samples, validate on 12097 samples
# Epoch 1/1
# 48387/48387 [==============================] - 1s 29us/step - loss: 0.7647 - val_loss: 0.7592
#
# Running Dataset:Tau_12: Epoch: 2: fileSet: 20
# Train on 48574 samples, validate on 12144 samples
# Epoch 1/1
# 48574/48574 [==============================] - 1s 29us/step - loss: 0.7582 - val_loss: 0.7950
#
# Running Dataset:Tau_12: Epoch: 2: fileSet: 8
# Train on 50045 samples, validate on 12512 samples
# Epoch 1/1
# 50045/50045 [==============================] - 1s 29us/step - loss: 0.6821 - val_loss: 0.7007
#
# Running Dataset:Tau_12: Epoch: 2: fileSet: 2
# Train on 50196 samples, validate on 12550 samples
# Epoch 1/1
# 50196/50196 [==============================] - 1s 29us/step - loss: 0.6040 - val_loss: 0.5952
#
# Running Dataset:Tau_12: Epoch: 2: fileSet: 18
# Train on 48241 samples, validate on 12061 samples
# Epoch 1/1
# 48241/48241 [==============================] - 1s 30us/step - loss: 0.7529 - val_loss: 0.7879
#
# Running Dataset:Tau_12: Epoch: 2: fileSet: 15
# Train on 48620 samples, validate on 12155 samples
# Epoch 1/1
# 48620/48620 [==============================] - 1s 29us/step - loss: 0.7141 - val_loss: 0.7290
#
# Running Dataset:Tau_12: Epoch: 2: fileSet: 1
# Train on 50302 samples, validate on 12576 samples
# Epoch 1/1
# 50302/50302 [==============================] - 1s 28us/step - loss: 0.6340 - val_loss: 0.6408
#
# Running Dataset:Tau_12: Epoch: 2: fileSet: 6
# Train on 50239 samples, validate on 12560 samples
# Epoch 1/1
# 50239/50239 [==============================] - 1s 28us/step - loss: 0.6771 - val_loss: 0.7219
#
# Running Dataset:Tau_12: Epoch: 3: fileSet: 17
# Train on 48541 samples, validate on 12136 samples
# Epoch 1/1
# 48541/48541 [==============================] - 1s 29us/step - loss: 0.7451 - val_loss: 0.7846
#
# Running Dataset:Tau_12: Epoch: 3: fileSet: 15
# Train on 48452 samples, validate on 12114 samples
# Epoch 1/1
# 48452/48452 [==============================] - 1s 29us/step - loss: 0.6881 - val_loss: 0.7045
#
# Running Dataset:Tau_12: Epoch: 3: fileSet: 10
# Train on 50233 samples, validate on 12559 samples
# Epoch 1/1
# 50233/50233 [==============================] - 1s 29us/step - loss: 0.6484 - val_loss: 0.6062
#
# Running Dataset:Tau_12: Epoch: 3: fileSet: 9
# Train on 50208 samples, validate on 12552 samples
# Epoch 1/1
# 50208/50208 [==============================] - 1s 29us/step - loss: 0.6391 - val_loss: 0.6429
#
# Running Dataset:Tau_12: Epoch: 3: fileSet: 18
# Train on 48440 samples, validate on 12110 samples
# Epoch 1/1
# 48440/48440 [==============================] - 1s 29us/step - loss: 0.7222 - val_loss: 0.7422
#
# Running Dataset:Tau_12: Epoch: 3: fileSet: 2
# Train on 50140 samples, validate on 12535 samples
# Epoch 1/1
# 50140/50140 [==============================] - 1s 29us/step - loss: 0.5980 - val_loss: 0.5560
#
# Running Dataset:Tau_12: Epoch: 3: fileSet: 3
# Train on 50222 samples, validate on 12556 samples
# Epoch 1/1
# 50222/50222 [==============================] - 1s 29us/step - loss: 0.6221 - val_loss: 0.4983
#
# Running Dataset:Tau_12: Epoch: 3: fileSet: 6
# Train on 50158 samples, validate on 12540 samples
# Epoch 1/1
# 50158/50158 [==============================] - 1s 30us/step - loss: 0.6497 - val_loss: 0.7128
#
# Running Dataset:Tau_12: Epoch: 3: fileSet: 4
# Train on 50193 samples, validate on 12549 samples
# Epoch 1/1
# 50193/50193 [==============================] - 1s 29us/step - loss: 0.6230 - val_loss: 0.8031
#
# Running Dataset:Tau_12: Epoch: 3: fileSet: 13
# Train on 48420 samples, validate on 12105 samples
# Epoch 1/1
# 48420/48420 [==============================] - 1s 29us/step - loss: 0.7417 - val_loss: 0.7307
#
# Running Dataset:Tau_12: Epoch: 3: fileSet: 16
# Train on 48527 samples, validate on 12132 samples
# Epoch 1/1
# 48527/48527 [==============================] - 2s 35us/step - loss: 0.6810 - val_loss: 0.6890
#
# Running Dataset:Tau_12: Epoch: 3: fileSet: 5
# Train on 50383 samples, validate on 12596 samples
# Epoch 1/1
# 50383/50383 [==============================] - 1s 29us/step - loss: 0.6211 - val_loss: 0.6598
#
# Running Dataset:Tau_12: Epoch: 3: fileSet: 1
# Train on 50359 samples, validate on 12590 samples
# Epoch 1/1
# 50359/50359 [==============================] - 1s 29us/step - loss: 0.5863 - val_loss: 0.6098
#
# Running Dataset:Tau_12: Epoch: 3: fileSet: 7
# Train on 50319 samples, validate on 12580 samples
# Epoch 1/1
# 50319/50319 [==============================] - 1s 30us/step - loss: 0.6536 - val_loss: 0.5748
#
# Running Dataset:Tau_12: Epoch: 3: fileSet: 8
# Train on 50025 samples, validate on 12507 samples
# Epoch 1/1
# 50025/50025 [==============================] - 1s 29us/step - loss: 0.6317 - val_loss: 0.6547
#
# Running Dataset:Tau_12: Epoch: 3: fileSet: 19
# Train on 48356 samples, validate on 12089 samples
# Epoch 1/1
# 48356/48356 [==============================] - 1s 29us/step - loss: 0.8356 - val_loss: 0.7464
#
# Running Dataset:Tau_12: Epoch: 3: fileSet: 11
# Train on 48430 samples, validate on 12108 samples
# Epoch 1/1
# 48430/48430 [==============================] - 1s 28us/step - loss: 0.7122 - val_loss: 0.7339
#
# Running Dataset:Tau_12: Epoch: 3: fileSet: 20
# Train on 48532 samples, validate on 12134 samples
# Epoch 1/1
# 48532/48532 [==============================] - 1s 29us/step - loss: 0.7180 - val_loss: 0.7608
#
# Running Dataset:Tau_12: Epoch: 3: fileSet: 12
# Train on 48369 samples, validate on 12093 samples
# Epoch 1/1
# 48369/48369 [==============================] - 1s 29us/step - loss: 0.6876 - val_loss: 0.6918
#
# Running Dataset:Tau_12: Epoch: 3: fileSet: 14
# Train on 48444 samples, validate on 12112 samples
# Epoch 1/1
# 48444/48444 [==============================] - 1s 28us/step - loss: 0.6677 - val_loss: 0.6305
#
# Running Dataset:Tau_12: Epoch: 4: fileSet: 7
# Train on 50280 samples, validate on 12571 samples
# Epoch 1/1
# 50280/50280 [==============================] - 1s 29us/step - loss: 0.6385 - val_loss: 0.6245
#
# Running Dataset:Tau_12: Epoch: 4: fileSet: 6
# Train on 50087 samples, validate on 12522 samples
# Epoch 1/1
# 50087/50087 [==============================] - 1s 30us/step - loss: 0.6238 - val_loss: 0.6910
#
# Running Dataset:Tau_12: Epoch: 4: fileSet: 2
# Train on 50270 samples, validate on 12568 samples
# Epoch 1/1
# 50270/50270 [==============================] - 1s 30us/step - loss: 0.5630 - val_loss: 0.5171
#
# Running Dataset:Tau_12: Epoch: 4: fileSet: 12
# Train on 48342 samples, validate on 12086 samples
# Epoch 1/1
# 48342/48342 [==============================] - 1s 29us/step - loss: 0.6712 - val_loss: 0.7002
#
# Running Dataset:Tau_12: Epoch: 4: fileSet: 16
# Train on 48569 samples, validate on 12143 samples
# Epoch 1/1
# 48569/48569 [==============================] - 1s 29us/step - loss: 0.6527 - val_loss: 0.7028
#
# Running Dataset:Tau_12: Epoch: 4: fileSet: 19
# Train on 48477 samples, validate on 12120 samples
# Epoch 1/1
# 48477/48477 [==============================] - 1s 28us/step - loss: 0.7545 - val_loss: 0.6961
#
# Running Dataset:Tau_12: Epoch: 4: fileSet: 4
# Train on 50184 samples, validate on 12547 samples
# Epoch 1/1
# 50184/50184 [==============================] - 2s 32us/step - loss: 0.6180 - val_loss: 0.8058
#
# Running Dataset:Tau_12: Epoch: 4: fileSet: 20
# Train on 48284 samples, validate on 12072 samples
# Epoch 1/1
# 48284/48284 [==============================] - 1s 29us/step - loss: 0.6969 - val_loss: 0.7215
#
# Running Dataset:Tau_12: Epoch: 4: fileSet: 10
# Train on 50329 samples, validate on 12583 samples
# Epoch 1/1
# 50329/50329 [==============================] - 1s 29us/step - loss: 0.6121 - val_loss: 0.6105
#
# Running Dataset:Tau_12: Epoch: 4: fileSet: 13
# Train on 48543 samples, validate on 12136 samples
# Epoch 1/1
# 48543/48543 [==============================] - 1s 29us/step - loss: 0.7054 - val_loss: 0.6943
#
# Running Dataset:Tau_12: Epoch: 4: fileSet: 11
# Train on 48613 samples, validate on 12154 samples
# Epoch 1/1
# 48613/48613 [==============================] - 1s 29us/step - loss: 0.6690 - val_loss: 0.6827
#
# Running Dataset:Tau_12: Epoch: 4: fileSet: 3
# Train on 50137 samples, validate on 12535 samples
# Epoch 1/1
# 50137/50137 [==============================] - 1s 29us/step - loss: 0.5969 - val_loss: 0.4785
#
# Running Dataset:Tau_12: Epoch: 4: fileSet: 8
# Train on 50300 samples, validate on 12576 samples
# Epoch 1/1
# 50300/50300 [==============================] - 1s 29us/step - loss: 0.6002 - val_loss: 0.6409
#
# Running Dataset:Tau_12: Epoch: 4: fileSet: 1
# Train on 50083 samples, validate on 12521 samples
# Epoch 1/1
# 50083/50083 [==============================] - 1s 29us/step - loss: 0.5596 - val_loss: 0.6011
#
# Running Dataset:Tau_12: Epoch: 4: fileSet: 17
# Train on 48686 samples, validate on 12172 samples
# Epoch 1/1
# 48686/48686 [==============================] - 1s 29us/step - loss: 0.7090 - val_loss: 0.7399
#
# Running Dataset:Tau_12: Epoch: 4: fileSet: 14
# Train on 48464 samples, validate on 12116 samples
# Epoch 1/1
# 48464/48464 [==============================] - 1s 29us/step - loss: 0.6386 - val_loss: 0.6307
#
# Running Dataset:Tau_12: Epoch: 4: fileSet: 18
# Train on 48632 samples, validate on 12159 samples
# Epoch 1/1
# 48632/48632 [==============================] - 1s 29us/step - loss: 0.6636 - val_loss: 0.7021
#
# Running Dataset:Tau_12: Epoch: 4: fileSet: 15
# Train on 48440 samples, validate on 12111 samples
# Epoch 1/1
# 48440/48440 [==============================] - 2s 32us/step - loss: 0.6355 - val_loss: 0.6348
#
# Running Dataset:Tau_12: Epoch: 4: fileSet: 9
# Train on 50196 samples, validate on 12550 samples
# Epoch 1/1
# 50196/50196 [==============================] - 1s 29us/step - loss: 0.5943 - val_loss: 0.5753
#
# Running Dataset:Tau_12: Epoch: 4: fileSet: 5
# Train on 50313 samples, validate on 12579 samples
# Epoch 1/1
# 50313/50313 [==============================] - 1s 30us/step - loss: 0.5732 - val_loss: 0.6336
#
# Running Dataset:Tau_12: Epoch: 5: fileSet: 14
# Train on 48448 samples, validate on 12112 samples
# Epoch 1/1
# 48448/48448 [==============================] - 1s 29us/step - loss: 0.6277 - val_loss: 0.6184
#
# Running Dataset:Tau_12: Epoch: 5: fileSet: 2
# Train on 50159 samples, validate on 12540 samples
# Epoch 1/1
# 50159/50159 [==============================] - 1s 29us/step - loss: 0.5439 - val_loss: 0.5265
#
# Running Dataset:Tau_12: Epoch: 5: fileSet: 19
# Train on 48252 samples, validate on 12064 samples
# Epoch 1/1
# 48252/48252 [==============================] - 1s 29us/step - loss: 0.7473 - val_loss: 0.7249
#
# Running Dataset:Tau_12: Epoch: 5: fileSet: 4
# Train on 50120 samples, validate on 12530 samples
# Epoch 1/1
# 50120/50120 [==============================] - 1s 29us/step - loss: 0.5798 - val_loss: 0.8024
#
# Running Dataset:Tau_12: Epoch: 5: fileSet: 18
# Train on 48603 samples, validate on 12151 samples
# Epoch 1/1
# 48603/48603 [==============================] - 1s 28us/step - loss: 0.6535 - val_loss: 0.7183
#
# Running Dataset:Tau_12: Epoch: 5: fileSet: 16
# Train on 48373 samples, validate on 12094 samples
# Epoch 1/1
# 48373/48373 [==============================] - 1s 29us/step - loss: 0.6286 - val_loss: 0.6855
#
# Running Dataset:Tau_12: Epoch: 5: fileSet: 17
# Train on 48538 samples, validate on 12135 samples
# Epoch 1/1
# 48538/48538 [==============================] - 1s 30us/step - loss: 0.6483 - val_loss: 0.7133
#
# Running Dataset:Tau_12: Epoch: 5: fileSet: 20
# Train on 48328 samples, validate on 12083 samples
# Epoch 1/1
# 48328/48328 [==============================] - 2s 31us/step - loss: 0.6381 - val_loss: 0.7132
#
# Running Dataset:Tau_12: Epoch: 5: fileSet: 3
# Train on 50417 samples, validate on 12605 samples
# Epoch 1/1
# 50417/50417 [==============================] - 1s 29us/step - loss: 0.5879 - val_loss: 0.4593
#
# Running Dataset:Tau_12: Epoch: 5: fileSet: 6
# Train on 50245 samples, validate on 12562 samples
# Epoch 1/1
# 50245/50245 [==============================] - 1s 30us/step - loss: 0.6019 - val_loss: 0.6811
#
# Running Dataset:Tau_12: Epoch: 5: fileSet: 13
# Train on 48425 samples, validate on 12107 samples
# Epoch 1/1
# 48425/48425 [==============================] - 1s 30us/step - loss: 0.6924 - val_loss: 0.6752
#
# Running Dataset:Tau_12: Epoch: 5: fileSet: 10
# Train on 50260 samples, validate on 12565 samples
# Epoch 1/1
# 50260/50260 [==============================] - 2s 30us/step - loss: 0.5852 - val_loss: 0.5753
#
# Running Dataset:Tau_12: Epoch: 5: fileSet: 11
# Train on 48444 samples, validate on 12111 samples
# Epoch 1/1
# 48444/48444 [==============================] - 1s 30us/step - loss: 0.6472 - val_loss: 0.6625
#
# Running Dataset:Tau_12: Epoch: 5: fileSet: 15
# Train on 48475 samples, validate on 12119 samples
# Epoch 1/1
# 48475/48475 [==============================] - 1s 30us/step - loss: 0.6187 - val_loss: 0.6164
#
# Running Dataset:Tau_12: Epoch: 5: fileSet: 1
# Train on 50268 samples, validate on 12568 samples
# Epoch 1/1
# 50268/50268 [==============================] - 2s 32us/step - loss: 0.5364 - val_loss: 0.5987
#
# Running Dataset:Tau_12: Epoch: 5: fileSet: 9
# Train on 50355 samples, validate on 12589 samples
# Epoch 1/1
# 50355/50355 [==============================] - 2s 35us/step - loss: 0.5459 - val_loss: 0.6356
#
# Running Dataset:Tau_12: Epoch: 5: fileSet: 8
# Train on 50168 samples, validate on 12542 samples
# Epoch 1/1
# 50168/50168 [==============================] - 2s 35us/step - loss: 0.5643 - val_loss: 0.6600
#
# Running Dataset:Tau_12: Epoch: 5: fileSet: 5
# Train on 50381 samples, validate on 12596 samples
# Epoch 1/1
# 50381/50381 [==============================] - 2s 31us/step - loss: 0.5762 - val_loss: 0.5900
#
# Running Dataset:Tau_12: Epoch: 5: fileSet: 7
# Train on 50304 samples, validate on 12576 samples
# Epoch 1/1
# 50304/50304 [==============================] - 1s 29us/step - loss: 0.6035 - val_loss: 0.5382
#
# Running Dataset:Tau_12: Epoch: 5: fileSet: 12
# Train on 48382 samples, validate on 12096 samples
# Epoch 1/1
# 48382/48382 [==============================] - 1s 29us/step - loss: 0.6545 - val_loss: 0.6621
#
# Running Dataset:Tau_12: Epoch: 6: fileSet: 7
# Train on 50281 samples, validate on 12571 samples
# Epoch 1/1
# 50281/50281 [==============================] - 1s 29us/step - loss: 0.5505 - val_loss: 0.5529
#
# Running Dataset:Tau_12: Epoch: 6: fileSet: 20
# Train on 48477 samples, validate on 12120 samples
# Epoch 1/1
# 48477/48477 [==============================] - 1s 29us/step - loss: 0.6670 - val_loss: 0.7346
#
# Running Dataset:Tau_12: Epoch: 6: fileSet: 6
# Train on 50164 samples, validate on 12541 samples
# Epoch 1/1
# 50164/50164 [==============================] - 1s 29us/step - loss: 0.5960 - val_loss: 0.6738
#
# Running Dataset:Tau_12: Epoch: 6: fileSet: 17
# Train on 48333 samples, validate on 12084 samples
# Epoch 1/1
# 48333/48333 [==============================] - 1s 29us/step - loss: 0.6505 - val_loss: 0.7053
#
# Running Dataset:Tau_12: Epoch: 6: fileSet: 8
# Train on 50380 samples, validate on 12596 samples
# Epoch 1/1
# 50380/50380 [==============================] - 1s 30us/step - loss: 0.5705 - val_loss: 0.6282
#
# Running Dataset:Tau_12: Epoch: 6: fileSet: 2
# Train on 50250 samples, validate on 12563 samples
# Epoch 1/1
# 50250/50250 [==============================] - 2s 30us/step - loss: 0.5066 - val_loss: 0.4809
#
# Running Dataset:Tau_12: Epoch: 6: fileSet: 12
# Train on 48452 samples, validate on 12114 samples
# Epoch 1/1
# 48452/48452 [==============================] - 1s 31us/step - loss: 0.6229 - val_loss: 0.6628
#
# Running Dataset:Tau_12: Epoch: 6: fileSet: 15
# Train on 48536 samples, validate on 12135 samples
# Epoch 1/1
# 48536/48536 [==============================] - 1s 29us/step - loss: 0.5961 - val_loss: 0.6241
#
# Running Dataset:Tau_12: Epoch: 6: fileSet: 3
# Train on 50249 samples, validate on 12563 samples
# Epoch 1/1
# 50249/50249 [==============================] - 2s 30us/step - loss: 0.5714 - val_loss: 0.4624
#
# Running Dataset:Tau_12: Epoch: 6: fileSet: 14
# Train on 48438 samples, validate on 12110 samples
# Epoch 1/1
# 48438/48438 [==============================] - 1s 29us/step - loss: 0.6276 - val_loss: 0.6016
#
# Running Dataset:Tau_12: Epoch: 6: fileSet: 5
# Train on 50324 samples, validate on 12581 samples
# Epoch 1/1
# 50324/50324 [==============================] - 1s 29us/step - loss: 0.5577 - val_loss: 0.5887
#
# Running Dataset:Tau_12: Epoch: 6: fileSet: 4
# Train on 50221 samples, validate on 12556 samples
# Epoch 1/1
# 50221/50221 [==============================] - 1s 29us/step - loss: 0.5366 - val_loss: 0.7632
#
# Running Dataset:Tau_12: Epoch: 6: fileSet: 1
# Train on 50118 samples, validate on 12530 samples
# Epoch 1/1
# 50118/50118 [==============================] - 1s 29us/step - loss: 0.5035 - val_loss: 0.5861
#
# Running Dataset:Tau_12: Epoch: 6: fileSet: 10
# Train on 50239 samples, validate on 12560 samples
# Epoch 1/1
# 50239/50239 [==============================] - 1s 29us/step - loss: 0.5524 - val_loss: 0.5517
#
# Running Dataset:Tau_12: Epoch: 6: fileSet: 11
# Train on 48434 samples, validate on 12109 samples
# Epoch 1/1
# 48434/48434 [==============================] - 1s 29us/step - loss: 0.6367 - val_loss: 0.6858
#
# Running Dataset:Tau_12: Epoch: 6: fileSet: 19
# Train on 48318 samples, validate on 12080 samples
# Epoch 1/1
# 48318/48318 [==============================] - 1s 29us/step - loss: 0.6983 - val_loss: 0.6488
#
# Running Dataset:Tau_12: Epoch: 6: fileSet: 9
# Train on 50195 samples, validate on 12549 samples
# Epoch 1/1
# 50195/50195 [==============================] - 1s 30us/step - loss: 0.5488 - val_loss: 0.5867
#
# Running Dataset:Tau_12: Epoch: 6: fileSet: 18
# Train on 48492 samples, validate on 12123 samples
# Epoch 1/1
# 48492/48492 [==============================] - 1s 29us/step - loss: 0.6256 - val_loss: 0.7066
#
# Running Dataset:Tau_12: Epoch: 6: fileSet: 13
# Train on 48502 samples, validate on 12126 samples
# Epoch 1/1
# 48502/48502 [==============================] - 1s 29us/step - loss: 0.6372 - val_loss: 0.6611
#
# Running Dataset:Tau_12: Epoch: 6: fileSet: 16
# Train on 48455 samples, validate on 12114 samples
# Epoch 1/1
# 48455/48455 [==============================] - 1s 30us/step - loss: 0.5935 - val_loss: 0.6292
#
# Running Dataset:Tau_12: Epoch: 7: fileSet: 3
# Train on 50188 samples, validate on 12548 samples
# Epoch 1/1
# 50188/50188 [==============================] - 2s 30us/step - loss: 0.5499 - val_loss: 0.4530
#
# Running Dataset:Tau_12: Epoch: 7: fileSet: 10
# Train on 50256 samples, validate on 12565 samples
# Epoch 1/1
# 50256/50256 [==============================] - 1s 29us/step - loss: 0.5345 - val_loss: 0.5733
#
# Running Dataset:Tau_12: Epoch: 7: fileSet: 6
# Train on 50088 samples, validate on 12522 samples
# Epoch 1/1
# 50088/50088 [==============================] - 2s 37us/step - loss: 0.5521 - val_loss: 0.6767
#
# Running Dataset:Tau_12: Epoch: 7: fileSet: 19
# Train on 48492 samples, validate on 12124 samples
# Epoch 1/1
# 48492/48492 [==============================] - 1s 30us/step - loss: 0.7026 - val_loss: 0.6604
#
# Running Dataset:Tau_12: Epoch: 7: fileSet: 17
# Train on 48372 samples, validate on 12093 samples
# Epoch 1/1
# 48372/48372 [==============================] - 1s 30us/step - loss: 0.6210 - val_loss: 0.6750
#
# Running Dataset:Tau_12: Epoch: 7: fileSet: 16
# Train on 48564 samples, validate on 12141 samples
# Epoch 1/1
# 48564/48564 [==============================] - 1s 30us/step - loss: 0.5707 - val_loss: 0.6459
#
# Running Dataset:Tau_12: Epoch: 7: fileSet: 18
# Train on 48414 samples, validate on 12104 samples
# Epoch 1/1
# 48414/48414 [==============================] - 1s 30us/step - loss: 0.5895 - val_loss: 0.6761
#
# Running Dataset:Tau_12: Epoch: 7: fileSet: 11
# Train on 48461 samples, validate on 12116 samples
# Epoch 1/1
# 48461/48461 [==============================] - 1s 30us/step - loss: 0.5952 - val_loss: 0.6314
#
# Running Dataset:Tau_12: Epoch: 7: fileSet: 12
# Train on 48544 samples, validate on 12136 samples
# Epoch 1/1
# 48544/48544 [==============================] - 1s 29us/step - loss: 0.5791 - val_loss: 0.6450
#
# Running Dataset:Tau_12: Epoch: 7: fileSet: 4
# Train on 50239 samples, validate on 12560 samples
# Epoch 1/1
# 50239/50239 [==============================] - 1s 29us/step - loss: 0.5365 - val_loss: 0.7356
#
# Running Dataset:Tau_12: Epoch: 7: fileSet: 8
# Train on 50290 samples, validate on 12573 samples
# Epoch 1/1
# 50290/50290 [==============================] - 1s 30us/step - loss: 0.5403 - val_loss: 0.5803
#
# Running Dataset:Tau_12: Epoch: 7: fileSet: 7
# Train on 50185 samples, validate on 12547 samples
# Epoch 1/1
# 50185/50185 [==============================] - 1s 29us/step - loss: 0.5697 - val_loss: 0.5620
#
# Running Dataset:Tau_12: Epoch: 7: fileSet: 9
# Train on 50108 samples, validate on 12528 samples
# Epoch 1/1
# 50108/50108 [==============================] - 1s 30us/step - loss: 0.5247 - val_loss: 0.6025
#
# Running Dataset:Tau_12: Epoch: 7: fileSet: 13
# Train on 48289 samples, validate on 12073 samples
# Epoch 1/1
# 48289/48289 [==============================] - 1s 29us/step - loss: 0.6611 - val_loss: 0.6565
#
# Running Dataset:Tau_12: Epoch: 7: fileSet: 5
# Train on 50298 samples, validate on 12575 samples
# Epoch 1/1
# 50298/50298 [==============================] - 2s 30us/step - loss: 0.5604 - val_loss: 0.5950
#
# Running Dataset:Tau_12: Epoch: 7: fileSet: 14
# Train on 48574 samples, validate on 12144 samples
# Epoch 1/1
# 48574/48574 [==============================] - 1s 29us/step - loss: 0.6037 - val_loss: 0.5927
#
# Running Dataset:Tau_12: Epoch: 7: fileSet: 1
# Train on 50478 samples, validate on 12620 samples
# Epoch 1/1
# 50478/50478 [==============================] - 2s 30us/step - loss: 0.5024 - val_loss: 0.5491
#
# Running Dataset:Tau_12: Epoch: 7: fileSet: 15
# Train on 48395 samples, validate on 12099 samples
# Epoch 1/1
# 48395/48395 [==============================] - 1s 30us/step - loss: 0.5947 - val_loss: 0.6252
#
# Running Dataset:Tau_12: Epoch: 7: fileSet: 2
# Train on 50053 samples, validate on 12514 samples
# Epoch 1/1
# 50053/50053 [==============================] - 1s 29us/step - loss: 0.4926 - val_loss: 0.5507
#
# Running Dataset:Tau_12: Epoch: 7: fileSet: 20
# Train on 48433 samples, validate on 12109 samples
# Epoch 1/1
# 48433/48433 [==============================] - 1s 30us/step - loss: 0.6473 - val_loss: 0.6753
#
# Running Dataset:Tau_12: Epoch: 8: fileSet: 14
# Train on 48272 samples, validate on 12068 samples
# Epoch 1/1
# 48272/48272 [==============================] - 1s 30us/step - loss: 0.5522 - val_loss: 0.5674
#
# Running Dataset:Tau_12: Epoch: 8: fileSet: 17
# Train on 48391 samples, validate on 12098 samples
# Epoch 1/1
# 48391/48391 [==============================] - 1s 31us/step - loss: 0.5974 - val_loss: 0.6633
#
# Running Dataset:Tau_12: Epoch: 8: fileSet: 20
# Train on 48328 samples, validate on 12083 samples
# Epoch 1/1
# 48328/48328 [==============================] - 1s 30us/step - loss: 0.5757 - val_loss: 0.6575
#
# Running Dataset:Tau_12: Epoch: 8: fileSet: 1
# Train on 50198 samples, validate on 12550 samples
# Epoch 1/1
# 50198/50198 [==============================] - 2s 31us/step - loss: 0.4967 - val_loss: 0.5831
#
# Running Dataset:Tau_12: Epoch: 8: fileSet: 11
# Train on 48512 samples, validate on 12128 samples
# Epoch 1/1
# 48512/48512 [==============================] - 1s 30us/step - loss: 0.6034 - val_loss: 0.6301
#
# Running Dataset:Tau_12: Epoch: 8: fileSet: 18
# Train on 48267 samples, validate on 12067 samples
# Epoch 1/1
# 48267/48267 [==============================] - 1s 30us/step - loss: 0.5921 - val_loss: 0.6614
#
# Running Dataset:Tau_12: Epoch: 8: fileSet: 6
# Train on 50196 samples, validate on 12549 samples
# Epoch 1/1
# 50196/50196 [==============================] - 1s 30us/step - loss: 0.5596 - val_loss: 0.6637
#
# Running Dataset:Tau_12: Epoch: 8: fileSet: 15
# Train on 48525 samples, validate on 12132 samples
# Epoch 1/1
# 48525/48525 [==============================] - 1s 29us/step - loss: 0.5877 - val_loss: 0.5835
#
# Running Dataset:Tau_12: Epoch: 8: fileSet: 19
# Train on 48562 samples, validate on 12141 samples
# Epoch 1/1
# 48562/48562 [==============================] - 1s 31us/step - loss: 0.6615 - val_loss: 0.6309
#
# Running Dataset:Tau_12: Epoch: 8: fileSet: 7
# Train on 50259 samples, validate on 12565 samples
# Epoch 1/1
# 50259/50259 [==============================] - 1s 29us/step - loss: 0.5684 - val_loss: 0.5241
#
# Running Dataset:Tau_12: Epoch: 8: fileSet: 5
# Train on 50156 samples, validate on 12539 samples
# Epoch 1/1
# 50156/50156 [==============================] - 2s 30us/step - loss: 0.5171 - val_loss: 0.5931
#
# Running Dataset:Tau_12: Epoch: 8: fileSet: 12
# Train on 48320 samples, validate on 12080 samples
# Epoch 1/1
# 48320/48320 [==============================] - 1s 30us/step - loss: 0.6008 - val_loss: 0.6456
#
# Running Dataset:Tau_12: Epoch: 8: fileSet: 16
# Train on 48444 samples, validate on 12111 samples
# Epoch 1/1
# 48444/48444 [==============================] - 1s 30us/step - loss: 0.5665 - val_loss: 0.6175
#
# Running Dataset:Tau_12: Epoch: 8: fileSet: 10
# Train on 50236 samples, validate on 12560 samples
# Epoch 1/1
# 50236/50236 [==============================] - 1s 29us/step - loss: 0.5241 - val_loss: 0.5566
#
# Running Dataset:Tau_12: Epoch: 8: fileSet: 3
# Train on 50316 samples, validate on 12579 samples
# Epoch 1/1
# 50316/50316 [==============================] - 2s 30us/step - loss: 0.5170 - val_loss: 0.4447
#
# Running Dataset:Tau_12: Epoch: 8: fileSet: 8
# Train on 50270 samples, validate on 12568 samples
# Epoch 1/1
# 50270/50270 [==============================] - 1s 29us/step - loss: 0.5210 - val_loss: 0.6204
#
# Running Dataset:Tau_12: Epoch: 8: fileSet: 13
# Train on 48424 samples, validate on 12107 samples
# Epoch 1/1
# 48424/48424 [==============================] - 1s 30us/step - loss: 0.6142 - val_loss: 0.6482
#
# Running Dataset:Tau_12: Epoch: 8: fileSet: 2
# Train on 50385 samples, validate on 12597 samples
# Epoch 1/1
# 50385/50385 [==============================] - 1s 29us/step - loss: 0.5011 - val_loss: 0.4966
#
# Running Dataset:Tau_12: Epoch: 8: fileSet: 4
# Train on 50246 samples, validate on 12562 samples
# Epoch 1/1
# 50246/50246 [==============================] - 2s 30us/step - loss: 0.5033 - val_loss: 0.7413
#
# Running Dataset:Tau_12: Epoch: 8: fileSet: 9
# Train on 50445 samples, validate on 12612 samples
# Epoch 1/1
# 50445/50445 [==============================] - 1s 29us/step - loss: 0.4936 - val_loss: 0.5648
#
# Running Dataset:Tau_12: Epoch: 9: fileSet: 11
# Train on 48544 samples, validate on 12136 samples
# Epoch 1/1
# 48544/48544 [==============================] - 1s 30us/step - loss: 0.5943 - val_loss: 0.6349
#
# Running Dataset:Tau_12: Epoch: 9: fileSet: 12
# Train on 48476 samples, validate on 12120 samples
# Epoch 1/1
# 48476/48476 [==============================] - 1s 29us/step - loss: 0.5591 - val_loss: 0.6235
#
# Running Dataset:Tau_12: Epoch: 9: fileSet: 18
# Train on 48551 samples, validate on 12138 samples
# Epoch 1/1
# 48551/48551 [==============================] - 1s 30us/step - loss: 0.5630 - val_loss: 0.6591
#
# Running Dataset:Tau_12: Epoch: 9: fileSet: 8
# Train on 50089 samples, validate on 12523 samples
# Epoch 1/1
# 50089/50089 [==============================] - 2s 31us/step - loss: 0.5102 - val_loss: 0.5906
#
# Running Dataset:Tau_12: Epoch: 9: fileSet: 10
# Train on 50204 samples, validate on 12551 samples
# Epoch 1/1
# 50204/50204 [==============================] - 1s 29us/step - loss: 0.5311 - val_loss: 0.5359
#
# Running Dataset:Tau_12: Epoch: 9: fileSet: 7
# Train on 50363 samples, validate on 12591 samples
# Epoch 1/1
# 50363/50363 [==============================] - 1s 29us/step - loss: 0.5525 - val_loss: 0.4966
#
# Running Dataset:Tau_12: Epoch: 9: fileSet: 4
# Train on 50404 samples, validate on 12601 samples
# Epoch 1/1
# 50404/50404 [==============================] - 2s 30us/step - loss: 0.4959 - val_loss: 0.7392
#
# Running Dataset:Tau_12: Epoch: 9: fileSet: 6
# Train on 50328 samples, validate on 12582 samples
# Epoch 1/1
# 50328/50328 [==============================] - 2s 30us/step - loss: 0.5255 - val_loss: 0.6013
#
# Running Dataset:Tau_12: Epoch: 9: fileSet: 5
# Train on 50199 samples, validate on 12550 samples
# Epoch 1/1
# 50199/50199 [==============================] - 2s 36us/step - loss: 0.4939 - val_loss: 0.5901
#
# Running Dataset:Tau_12: Epoch: 9: fileSet: 2
# Train on 50188 samples, validate on 12547 samples
# Epoch 1/1
# 50188/50188 [==============================] - 2s 37us/step - loss: 0.4617 - val_loss: 0.4759
#
# Running Dataset:Tau_12: Epoch: 9: fileSet: 20
# Train on 48689 samples, validate on 12173 samples
# Epoch 1/1
# 48689/48689 [==============================] - 1s 29us/step - loss: 0.6190 - val_loss: 0.6561
#
# Running Dataset:Tau_12: Epoch: 9: fileSet: 13
# Train on 48420 samples, validate on 12105 samples
# Epoch 1/1
# 48420/48420 [==============================] - 1s 29us/step - loss: 0.5979 - val_loss: 0.6378
#
# Running Dataset:Tau_12: Epoch: 9: fileSet: 19
# Train on 48535 samples, validate on 12134 samples
# Epoch 1/1
# 48535/48535 [==============================] - 1s 30us/step - loss: 0.6491 - val_loss: 0.6280
#
# Running Dataset:Tau_12: Epoch: 9: fileSet: 16
# Train on 48369 samples, validate on 12093 samples
# Epoch 1/1
# 48369/48369 [==============================] - 1s 30us/step - loss: 0.5589 - val_loss: 0.6348
#
# Running Dataset:Tau_12: Epoch: 9: fileSet: 1
# Train on 50080 samples, validate on 12520 samples
# Epoch 1/1
# 50080/50080 [==============================] - 2s 31us/step - loss: 0.4874 - val_loss: 0.5397
#
# Running Dataset:Tau_12: Epoch: 9: fileSet: 3
# Train on 50122 samples, validate on 12531 samples
# Epoch 1/1
# 50122/50122 [==============================] - 1s 30us/step - loss: 0.5125 - val_loss: 0.4192
#
# Running Dataset:Tau_12: Epoch: 9: fileSet: 15
# Train on 48467 samples, validate on 12117 samples
# Epoch 1/1
# 48467/48467 [==============================] - 1s 30us/step - loss: 0.5841 - val_loss: 0.5941
#
# Running Dataset:Tau_12: Epoch: 9: fileSet: 17
# Train on 48382 samples, validate on 12096 samples
# Epoch 1/1
# 48382/48382 [==============================] - 1s 30us/step - loss: 0.5837 - val_loss: 0.6589
#
# Running Dataset:Tau_12: Epoch: 9: fileSet: 14
# Train on 48454 samples, validate on 12114 samples
# Epoch 1/1
# 48454/48454 [==============================] - 1s 30us/step - loss: 0.5448 - val_loss: 0.5694
#
# Running Dataset:Tau_12: Epoch: 9: fileSet: 9
# Train on 50336 samples, validate on 12584 samples
# Epoch 1/1
# 50336/50336 [==============================] - 2s 30us/step - loss: 0.5090 - val_loss: 0.5731
#
# Running Dataset:Tau_12: Epoch: 10: fileSet: 18
# Train on 48385 samples, validate on 12097 samples
# Epoch 1/1
# 48385/48385 [==============================] - 1s 30us/step - loss: 0.5681 - val_loss: 0.6383
#
# Running Dataset:Tau_12: Epoch: 10: fileSet: 20
# Train on 48580 samples, validate on 12145 samples
# Epoch 1/1
# 48580/48580 [==============================] - 1s 30us/step - loss: 0.5715 - val_loss: 0.6595
#
# Running Dataset:Tau_12: Epoch: 10: fileSet: 11
# Train on 48434 samples, validate on 12109 samples
# Epoch 1/1
# 48434/48434 [==============================] - 1s 30us/step - loss: 0.5599 - val_loss: 0.6035
#
# Running Dataset:Tau_12: Epoch: 10: fileSet: 1
# Train on 50347 samples, validate on 12587 samples
# Epoch 1/1
# 50347/50347 [==============================] - 1s 30us/step - loss: 0.4888 - val_loss: 0.5663
#
# Running Dataset:Tau_12: Epoch: 10: fileSet: 8
# Train on 50200 samples, validate on 12550 samples
# Epoch 1/1
# 50200/50200 [==============================] - 1s 30us/step - loss: 0.5010 - val_loss: 0.5876
#
# Running Dataset:Tau_12: Epoch: 10: fileSet: 9
# Train on 50223 samples, validate on 12556 samples
# Epoch 1/1
# 50223/50223 [==============================] - 1s 30us/step - loss: 0.4680 - val_loss: 0.5404
#
# Running Dataset:Tau_12: Epoch: 10: fileSet: 6
# Train on 50236 samples, validate on 12559 samples
# Epoch 1/1
# 50236/50236 [==============================] - 2s 30us/step - loss: 0.4996 - val_loss: 0.6149
#
# Running Dataset:Tau_12: Epoch: 10: fileSet: 15
# Train on 48484 samples, validate on 12121 samples
# Epoch 1/1
# 48484/48484 [==============================] - 1s 30us/step - loss: 0.5568 - val_loss: 0.5970
#
# Running Dataset:Tau_12: Epoch: 10: fileSet: 12
# Train on 48358 samples, validate on 12090 samples
# Epoch 1/1
# 48358/48358 [==============================] - 1s 30us/step - loss: 0.5575 - val_loss: 0.6190
#
# Running Dataset:Tau_12: Epoch: 10: fileSet: 13
# Train on 48364 samples, validate on 12092 samples
# Epoch 1/1
# 48364/48364 [==============================] - 1s 30us/step - loss: 0.5723 - val_loss: 0.6087
#
# Running Dataset:Tau_12: Epoch: 10: fileSet: 17
# Train on 48365 samples, validate on 12092 samples
# Epoch 1/1
# 48365/48365 [==============================] - 1s 31us/step - loss: 0.5629 - val_loss: 0.6215
#
# Running Dataset:Tau_12: Epoch: 10: fileSet: 19
# Train on 48466 samples, validate on 12117 samples
# Epoch 1/1
# 48466/48466 [==============================] - 1s 31us/step - loss: 0.6232 - val_loss: 0.6141
#
# Running Dataset:Tau_12: Epoch: 10: fileSet: 3
# Train on 50258 samples, validate on 12565 samples
# Epoch 1/1
# 50258/50258 [==============================] - 2s 31us/step - loss: 0.5111 - val_loss: 0.4390
#
# Running Dataset:Tau_12: Epoch: 10: fileSet: 2
# Train on 50276 samples, validate on 12570 samples
# Epoch 1/1
# 50276/50276 [==============================] - 2s 36us/step - loss: 0.4711 - val_loss: 0.4845
#
# Running Dataset:Tau_12: Epoch: 10: fileSet: 5
# Train on 50071 samples, validate on 12518 samples
# Epoch 1/1
# 50071/50071 [==============================] - 2s 34us/step - loss: 0.4881 - val_loss: 0.5792
#
# Running Dataset:Tau_12: Epoch: 10: fileSet: 16
# Train on 48526 samples, validate on 12132 samples
# Epoch 1/1
# 48526/48526 [==============================] - 1s 30us/step - loss: 0.5771 - val_loss: 0.6202
#
# Running Dataset:Tau_12: Epoch: 10: fileSet: 14
# Train on 48427 samples, validate on 12107 samples
# Epoch 1/1
# 48427/48427 [==============================] - 1s 31us/step - loss: 0.5329 - val_loss: 0.5514
#
# Running Dataset:Tau_12: Epoch: 10: fileSet: 4
# Train on 50308 samples, validate on 12578 samples
# Epoch 1/1
# 50308/50308 [==============================] - 2s 31us/step - loss: 0.5038 - val_loss: 0.7241
#
# Running Dataset:Tau_12: Epoch: 10: fileSet: 10
# Train on 50133 samples, validate on 12534 samples
# Epoch 1/1
# 50133/50133 [==============================] - 1s 30us/step - loss: 0.4981 - val_loss: 0.5104
#
# Running Dataset:Tau_12: Epoch: 10: fileSet: 7
# Train on 50332 samples, validate on 12584 samples
# Epoch 1/1
# 50332/50332 [==============================] - 2s 30us/step - loss: 0.5172 - val_loss: 0.5255
#
# Running Dataset:Tau_12: Epoch: 11: fileSet: 10
# Train on 50085 samples, validate on 12522 samples
# Epoch 1/1
# 50085/50085 [==============================] - 2s 31us/step - loss: 0.4705 - val_loss: 0.5250
#
# Running Dataset:Tau_12: Epoch: 11: fileSet: 8
# Train on 50335 samples, validate on 12584 samples
# Epoch 1/1
# 50335/50335 [==============================] - 2s 31us/step - loss: 0.5046 - val_loss: 0.5698
#
# Running Dataset:Tau_12: Epoch: 11: fileSet: 3
# Train on 50240 samples, validate on 12561 samples
# Epoch 1/1
# 50240/50240 [==============================] - 2s 30us/step - loss: 0.4622 - val_loss: 0.4366
#
# Running Dataset:Tau_12: Epoch: 11: fileSet: 19
# Train on 48388 samples, validate on 12097 samples
# Epoch 1/1
# 48388/48388 [==============================] - 1s 31us/step - loss: 0.6555 - val_loss: 0.6271
#
# Running Dataset:Tau_12: Epoch: 11: fileSet: 14
# Train on 48619 samples, validate on 12155 samples
# Epoch 1/1
# 48619/48619 [==============================] - 1s 30us/step - loss: 0.5215 - val_loss: 0.5481
#
# Running Dataset:Tau_12: Epoch: 11: fileSet: 20
# Train on 48440 samples, validate on 12110 samples
# Epoch 1/1
# 48440/48440 [==============================] - 1s 30us/step - loss: 0.5698 - val_loss: 0.6305
#
# Running Dataset:Tau_12: Epoch: 11: fileSet: 6
# Train on 50219 samples, validate on 12555 samples
# Epoch 1/1
# 50219/50219 [==============================] - 2s 30us/step - loss: 0.5128 - val_loss: 0.6044
#
# Running Dataset:Tau_12: Epoch: 11: fileSet: 9
# Train on 50001 samples, validate on 12501 samples
# Epoch 1/1
# 50001/50001 [==============================] - 1s 29us/step - loss: 0.4871 - val_loss: 0.5524
#
# Running Dataset:Tau_12: Epoch: 11: fileSet: 18
# Train on 48535 samples, validate on 12134 samples
# Epoch 1/1
# 48535/48535 [==============================] - 2s 31us/step - loss: 0.5719 - val_loss: 0.6445
#
# Running Dataset:Tau_12: Epoch: 11: fileSet: 12
# Train on 48398 samples, validate on 12100 samples
# Epoch 1/1
# 48398/48398 [==============================] - 1s 31us/step - loss: 0.5449 - val_loss: 0.6094
#
# Running Dataset:Tau_12: Epoch: 11: fileSet: 4
# Train on 50144 samples, validate on 12537 samples
# Epoch 1/1
# 50144/50144 [==============================] - 2s 30us/step - loss: 0.4962 - val_loss: 0.7311
#
# Running Dataset:Tau_12: Epoch: 11: fileSet: 17
# Train on 48247 samples, validate on 12062 samples
# Epoch 1/1
# 48247/48247 [==============================] - 1s 30us/step - loss: 0.5833 - val_loss: 0.6322
#
# Running Dataset:Tau_12: Epoch: 11: fileSet: 5
# Train on 50324 samples, validate on 12582 samples
# Epoch 1/1
# 50324/50324 [==============================] - 1s 29us/step - loss: 0.4980 - val_loss: 0.5603
#
# Running Dataset:Tau_12: Epoch: 11: fileSet: 2
# Train on 50213 samples, validate on 12554 samples
# Epoch 1/1
# 50213/50213 [==============================] - 2s 31us/step - loss: 0.4513 - val_loss: 0.4857
#
# Running Dataset:Tau_12: Epoch: 11: fileSet: 7
# Train on 50297 samples, validate on 12575 samples
# Epoch 1/1
# 50297/50297 [==============================] - 1s 30us/step - loss: 0.5151 - val_loss: 0.4916
#
# Running Dataset:Tau_12: Epoch: 11: fileSet: 1
# Train on 50161 samples, validate on 12541 samples
# Epoch 1/1
# 50161/50161 [==============================] - 2s 30us/step - loss: 0.4537 - val_loss: 0.5643
#
# Running Dataset:Tau_12: Epoch: 11: fileSet: 16
# Train on 48393 samples, validate on 12099 samples
# Epoch 1/1
# 48393/48393 [==============================] - 1s 30us/step - loss: 0.5693 - val_loss: 0.6157
#
# Running Dataset:Tau_12: Epoch: 11: fileSet: 11
# Train on 48548 samples, validate on 12138 samples
# Epoch 1/1
# 48548/48548 [==============================] - 1s 31us/step - loss: 0.5575 - val_loss: 0.5949
#
# Running Dataset:Tau_12: Epoch: 11: fileSet: 15
# Train on 48428 samples, validate on 12107 samples
# Epoch 1/1
# ...
# Epoch 1/1
# 48410/48410 [==============================] - 1s 26us/step - loss: 0.3306 - val_loss: 0.4227
#
# Running Dataset:Tau_23: Epoch: 46: fileSet: 10
# Train on 50256 samples, validate on 12564 samples
# Epoch 1/1
# 50256/50256 [==============================] - 2s 31us/step - loss: 0.3100 - val_loss: 0.4196
#
# Running Dataset:Tau_23: Epoch: 46: fileSet: 20
# Train on 48475 samples, validate on 12119 samples
# Epoch 1/1
# 48475/48475 [==============================] - 1s 26us/step - loss: 0.3284 - val_loss: 0.4268
#
# Running Dataset:Tau_23: Epoch: 46: fileSet: 3
# Train on 50307 samples, validate on 12577 samples
# Epoch 1/1
# 50307/50307 [==============================] - 1s 25us/step - loss: 0.3182 - val_loss: 0.3552
#
# Running Dataset:Tau_23: Epoch: 46: fileSet: 11
# Train on 48381 samples, validate on 12096 samples
# Epoch 1/1
# 48381/48381 [==============================] - 1s 26us/step - loss: 0.3082 - val_loss: 0.4162
#
# Running Dataset:Tau_23: Epoch: 46: fileSet: 17
# Train on 48388 samples, validate on 12098 samples
# Epoch 1/1
# 48388/48388 [==============================] - 1s 27us/step - loss: 0.3032 - val_loss: 0.4229
#
# Running Dataset:Tau_23: Epoch: 46: fileSet: 15
# Train on 48400 samples, validate on 12101 samples
# Epoch 1/1
# 48400/48400 [==============================] - 1s 25us/step - loss: 0.3018 - val_loss: 0.4082
#
# Running Dataset:Tau_23: Epoch: 46: fileSet: 4
# Train on 50201 samples, validate on 12551 samples
# Epoch 1/1
# 50201/50201 [==============================] - 1s 25us/step - loss: 0.3116 - val_loss: 0.6378
#
# Running Dataset:Tau_23: Epoch: 46: fileSet: 8
# Train on 50282 samples, validate on 12571 samples
# Epoch 1/1
# 50282/50282 [==============================] - 1s 26us/step - loss: 0.3048 - val_loss: 0.4364
#
# Running Dataset:Tau_23: Epoch: 46: fileSet: 9
# Train on 50332 samples, validate on 12584 samples
# Epoch 1/1
# 50332/50332 [==============================] - 1s 26us/step - loss: 0.3036 - val_loss: 0.4224
#
# Running Dataset:Tau_23: Epoch: 46: fileSet: 1
# Train on 50234 samples, validate on 12559 samples
# Epoch 1/1
# 50234/50234 [==============================] - 1s 25us/step - loss: 0.3029 - val_loss: 0.3316
#
# Running Dataset:Tau_23: Epoch: 46: fileSet: 19
# Train on 48316 samples, validate on 12080 samples
# Epoch 1/1
# 48316/48316 [==============================] - 1s 25us/step - loss: 0.3690 - val_loss: 0.4133
#
# Running Dataset:Tau_23: Epoch: 46: fileSet: 7
# Train on 50316 samples, validate on 12579 samples
# Epoch 1/1
# 50316/50316 [==============================] - 1s 26us/step - loss: 0.3674 - val_loss: 0.3953
#
# Running Dataset:Tau_23: Epoch: 46: fileSet: 6
# Train on 50361 samples, validate on 12591 samples
# Epoch 1/1
# 50361/50361 [==============================] - 1s 25us/step - loss: 0.3153 - val_loss: 0.4518
#
# Running Dataset:Tau_23: Epoch: 46: fileSet: 2
# Train on 50187 samples, validate on 12547 samples
# Epoch 1/1
# 50187/50187 [==============================] - 1s 25us/step - loss: 0.2928 - val_loss: 0.3495
#
# Running Dataset:Tau_23: Epoch: 46: fileSet: 5
# Train on 50169 samples, validate on 12543 samples
# Epoch 1/1
# 50169/50169 [==============================] - 1s 25us/step - loss: 0.3115 - val_loss: 0.4271
#
# Running Dataset:Tau_23: Epoch: 46: fileSet: 12
# Train on 48472 samples, validate on 12118 samples
# Epoch 1/1
# 48472/48472 [==============================] - 1s 26us/step - loss: 0.3150 - val_loss: 0.4392
#
# Running Dataset:Tau_23: Epoch: 46: fileSet: 16
# Train on 48336 samples, validate on 12085 samples
# Epoch 1/1
# 48336/48336 [==============================] - 1s 26us/step - loss: 0.3183 - val_loss: 0.3707
#
# Running Dataset:Tau_23: Epoch: 46: fileSet: 14
# Train on 48440 samples, validate on 12111 samples
# Epoch 1/1
# 48440/48440 [==============================] - 2s 33us/step - loss: 0.2953 - val_loss: 0.3395
#
# Running Dataset:Tau_23: Epoch: 47: fileSet: 17
# Train on 48454 samples, validate on 12114 samples
# Epoch 1/1
# 48454/48454 [==============================] - 2s 36us/step - loss: 0.3026 - val_loss: 0.4000
#
# Running Dataset:Tau_23: Epoch: 47: fileSet: 1
# Train on 50196 samples, validate on 12550 samples
# Epoch 1/1
# 50196/50196 [==============================] - 2s 31us/step - loss: 0.3070 - val_loss: 0.3373
#
# Running Dataset:Tau_23: Epoch: 47: fileSet: 14
# Train on 48568 samples, validate on 12142 samples
# Epoch 1/1
# 48568/48568 [==============================] - 1s 26us/step - loss: 0.2916 - val_loss: 0.3451
#
# Running Dataset:Tau_23: Epoch: 47: fileSet: 20
# Train on 48489 samples, validate on 12123 samples
# Epoch 1/1
# 48489/48489 [==============================] - 1s 26us/step - loss: 0.3139 - val_loss: 0.4500
#
# Running Dataset:Tau_23: Epoch: 47: fileSet: 16
# Train on 48498 samples, validate on 12125 samples
# Epoch 1/1
# 48498/48498 [==============================] - 1s 26us/step - loss: 0.3072 - val_loss: 0.3772
#
# Running Dataset:Tau_23: Epoch: 47: fileSet: 18
# Train on 48424 samples, validate on 12107 samples
# Epoch 1/1
# 48424/48424 [==============================] - 1s 26us/step - loss: 0.2891 - val_loss: 0.4015
#
# Running Dataset:Tau_23: Epoch: 47: fileSet: 8
# Train on 50313 samples, validate on 12579 samples
# Epoch 1/1
# 50313/50313 [==============================] - 1s 27us/step - loss: 0.3006 - val_loss: 0.4095
#
# Running Dataset:Tau_23: Epoch: 47: fileSet: 15
# Train on 48577 samples, validate on 12145 samples
# Epoch 1/1
# 48577/48577 [==============================] - 1s 26us/step - loss: 0.3087 - val_loss: 0.3797
#
# Running Dataset:Tau_23: Epoch: 47: fileSet: 2
# Train on 50141 samples, validate on 12536 samples
# Epoch 1/1
# 50141/50141 [==============================] - 1s 26us/step - loss: 0.2943 - val_loss: 0.3583
#
# Running Dataset:Tau_23: Epoch: 47: fileSet: 3
# Train on 50204 samples, validate on 12552 samples
# Epoch 1/1
# 50204/50204 [==============================] - 1s 27us/step - loss: 0.3176 - val_loss: 0.3323
#
# Running Dataset:Tau_23: Epoch: 47: fileSet: 6
# Train on 50142 samples, validate on 12536 samples
# Epoch 1/1
# 50142/50142 [==============================] - 1s 26us/step - loss: 0.3117 - val_loss: 0.4708
#
# Running Dataset:Tau_23: Epoch: 47: fileSet: 4
# Train on 50236 samples, validate on 12560 samples
# Epoch 1/1
# 50236/50236 [==============================] - 1s 26us/step - loss: 0.3170 - val_loss: 0.6820
#
# Running Dataset:Tau_23: Epoch: 47: fileSet: 5
# Train on 50167 samples, validate on 12542 samples
# Epoch 1/1
# 50167/50167 [==============================] - 1s 25us/step - loss: 0.3154 - val_loss: 0.4164
#
# Running Dataset:Tau_23: Epoch: 47: fileSet: 19
# Train on 48428 samples, validate on 12107 samples
# Epoch 1/1
# 48428/48428 [==============================] - 1s 28us/step - loss: 0.3674 - val_loss: 0.4153
#
# Running Dataset:Tau_23: Epoch: 47: fileSet: 13
# Train on 48617 samples, validate on 12155 samples
# Epoch 1/1
# 48617/48617 [==============================] - 1s 26us/step - loss: 0.3430 - val_loss: 0.3947
#
# Running Dataset:Tau_23: Epoch: 47: fileSet: 12
# Train on 48397 samples, validate on 12100 samples
# Epoch 1/1
# 48397/48397 [==============================] - 1s 26us/step - loss: 0.3019 - val_loss: 0.4393
#
# Running Dataset:Tau_23: Epoch: 47: fileSet: 10
# Train on 50291 samples, validate on 12573 samples
# Epoch 1/1
# 50291/50291 [==============================] - 1s 26us/step - loss: 0.3129 - val_loss: 0.4399
#
# Running Dataset:Tau_23: Epoch: 47: fileSet: 7
# Train on 50172 samples, validate on 12543 samples
# Epoch 1/1
# 50172/50172 [==============================] - 1s 25us/step - loss: 0.3632 - val_loss: 0.3911
#
# Running Dataset:Tau_23: Epoch: 47: fileSet: 9
# Train on 50208 samples, validate on 12553 samples
# Epoch 1/1
# 50208/50208 [==============================] - 1s 25us/step - loss: 0.3106 - val_loss: 0.4132
#
# Running Dataset:Tau_23: Epoch: 47: fileSet: 11
# Train on 48329 samples, validate on 12083 samples
# Epoch 1/1
# 48329/48329 [==============================] - 1s 26us/step - loss: 0.3183 - val_loss: 0.3941
#
# Running Dataset:Tau_23: Epoch: 48: fileSet: 3
# Train on 50244 samples, validate on 12562 samples
# Epoch 1/1
# 50244/50244 [==============================] - 1s 27us/step - loss: 0.3145 - val_loss: 0.3352
#
# Running Dataset:Tau_23: Epoch: 48: fileSet: 13
# Train on 48413 samples, validate on 12104 samples
# Epoch 1/1
# 48413/48413 [==============================] - 1s 26us/step - loss: 0.3471 - val_loss: 0.3900
#
# Running Dataset:Tau_23: Epoch: 48: fileSet: 6
# Train on 50392 samples, validate on 12598 samples
# Epoch 1/1
# 50392/50392 [==============================] - 1s 26us/step - loss: 0.3115 - val_loss: 0.4565
#
# Running Dataset:Tau_23: Epoch: 48: fileSet: 18
# Train on 48478 samples, validate on 12120 samples
# Epoch 1/1
# 48478/48478 [==============================] - 1s 26us/step - loss: 0.2932 - val_loss: 0.3993
#
# Running Dataset:Tau_23: Epoch: 48: fileSet: 2
# Train on 50151 samples, validate on 12538 samples
# Epoch 1/1
# 50151/50151 [==============================] - 1s 26us/step - loss: 0.2912 - val_loss: 0.3546
#
# Running Dataset:Tau_23: Epoch: 48: fileSet: 4
# Train on 50174 samples, validate on 12544 samples
# Epoch 1/1
# 50174/50174 [==============================] - 1s 25us/step - loss: 0.3068 - val_loss: 0.6682
#
# Running Dataset:Tau_23: Epoch: 48: fileSet: 11
# Train on 48380 samples, validate on 12096 samples
# Epoch 1/1
# 48380/48380 [==============================] - 1s 27us/step - loss: 0.3054 - val_loss: 0.3886
#
# Running Dataset:Tau_23: Epoch: 48: fileSet: 20
# Train on 48343 samples, validate on 12086 samples
# Epoch 1/1
# 48343/48343 [==============================] - 1s 26us/step - loss: 0.3250 - val_loss: 0.4241
#
# Running Dataset:Tau_23: Epoch: 48: fileSet: 5
# Train on 50368 samples, validate on 12592 samples
# Epoch 1/1
# 50368/50368 [==============================] - 1s 27us/step - loss: 0.3083 - val_loss: 0.4260
#
# Running Dataset:Tau_23: Epoch: 48: fileSet: 17
# Train on 48546 samples, validate on 12137 samples
# Epoch 1/1
# 48546/48546 [==============================] - 1s 27us/step - loss: 0.3130 - val_loss: 0.3926
#
# Running Dataset:Tau_23: Epoch: 48: fileSet: 15
# Train on 48429 samples, validate on 12108 samples
# Epoch 1/1
# 48429/48429 [==============================] - 1s 27us/step - loss: 0.3032 - val_loss: 0.3788
# Running Dataset:Tau_23: Epoch: 48: fileSet: 12
# Train on 48405 samples, validate on 12102 samples
# Epoch 1/1
# 48405/48405 [==============================] - 1s 26us/step - loss: 0.2990 - val_loss: 0.4095
#
# Running Dataset:Tau_23: Epoch: 48: fileSet: 16
# Train on 48440 samples, validate on 12111 samples
# Epoch 1/1
# 48440/48440 [==============================] - 1s 26us/step - loss: 0.3084 - val_loss: 0.3536
#
# Running Dataset:Tau_23: Epoch: 48: fileSet: 1
# Train on 50356 samples, validate on 12589 samples
# Epoch 1/1
# 50356/50356 [==============================] - 1s 26us/step - loss: 0.2999 - val_loss: 0.3699
#
# Running Dataset:Tau_23: Epoch: 48: fileSet: 10
# Train on 50205 samples, validate on 12552 samples
# Epoch 1/1
# 50205/50205 [==============================] - 1s 25us/step - loss: 0.3103 - val_loss: 0.4506
#
# Running Dataset:Tau_23: Epoch: 48: fileSet: 14
# Train on 48472 samples, validate on 12119 samples
# Epoch 1/1
# 48472/48472 [==============================] - 1s 27us/step - loss: 0.3072 - val_loss: 0.3425
#
# Running Dataset:Tau_23: Epoch: 48: fileSet: 7
# Train on 50233 samples, validate on 12559 samples
# Epoch 1/1
# 50233/50233 [==============================] - 1s 25us/step - loss: 0.3577 - val_loss: 0.4368
#
# Running Dataset:Tau_23: Epoch: 48: fileSet: 8
# Train on 50233 samples, validate on 12559 samples
# Epoch 1/1
# 50233/50233 [==============================] - 1s 26us/step - loss: 0.2987 - val_loss: 0.4173
#
# Running Dataset:Tau_23: Epoch: 48: fileSet: 19
# Train on 48440 samples, validate on 12111 samples
# Epoch 1/1
# 48440/48440 [==============================] - 1s 27us/step - loss: 0.3658 - val_loss: 0.4105
#
# Running Dataset:Tau_23: Epoch: 48: fileSet: 9
# Train on 50300 samples, validate on 12576 samples
# Epoch 1/1
# 50300/50300 [==============================] - 1s 26us/step - loss: 0.3117 - val_loss: 0.4213
#
# Running Dataset:Tau_23: Epoch: 49: fileSet: 9
# Train on 50300 samples, validate on 12575 samples
# Epoch 1/1
# 50300/50300 [==============================] - 1s 26us/step - loss: 0.2736 - val_loss: 0.4203
#
# Running Dataset:Tau_23: Epoch: 49: fileSet: 12
# Train on 48521 samples, validate on 12131 samples
# Epoch 1/1
# 48521/48521 [==============================] - 1s 26us/step - loss: 0.2987 - val_loss: 0.3987
#
# Running Dataset:Tau_23: Epoch: 49: fileSet: 2
# Train on 50138 samples, validate on 12535 samples
# Epoch 1/1
# 50138/50138 [==============================] - 1s 25us/step - loss: 0.2982 - val_loss: 0.3600
#
# Running Dataset:Tau_23: Epoch: 49: fileSet: 7
# Train on 50184 samples, validate on 12547 samples
# Epoch 1/1
# 50184/50184 [==============================] - 2s 31us/step - loss: 0.3526 - val_loss: 0.3996
#
# Running Dataset:Tau_23: Epoch: 49: fileSet: 4
# Train on 50161 samples, validate on 12541 samples
# Epoch 1/1
# 50161/50161 [==============================] - 1s 28us/step - loss: 0.3159 - val_loss: 0.6455
#
# Running Dataset:Tau_23: Epoch: 49: fileSet: 5
# Train on 50122 samples, validate on 12531 samples
# Epoch 1/1
# 50122/50122 [==============================] - 1s 25us/step - loss: 0.3045 - val_loss: 0.4217
#
# Running Dataset:Tau_23: Epoch: 49: fileSet: 16
# Train on 48523 samples, validate on 12131 samples
# Epoch 1/1
# 48523/48523 [==============================] - 1s 26us/step - loss: 0.3192 - val_loss: 0.3639
#
# Running Dataset:Tau_23: Epoch: 49: fileSet: 14
# Train on 48360 samples, validate on 12091 samples
# Epoch 1/1
# 48360/48360 [==============================] - 1s 26us/step - loss: 0.2931 - val_loss: 0.3568
#
# Running Dataset:Tau_23: Epoch: 49: fileSet: 6
# Train on 50208 samples, validate on 12552 samples
# Epoch 1/1
# 50208/50208 [==============================] - 1s 26us/step - loss: 0.3125 - val_loss: 0.4355
#
# Running Dataset:Tau_23: Epoch: 49: fileSet: 18
# Train on 48446 samples, validate on 12112 samples
# Epoch 1/1
# 48446/48446 [==============================] - 1s 26us/step - loss: 0.2969 - val_loss: 0.3854
#
# Running Dataset:Tau_23: Epoch: 49: fileSet: 13
# Train on 48402 samples, validate on 12101 samples
# Epoch 1/1
# 48402/48402 [==============================] - 1s 27us/step - loss: 0.3324 - val_loss: 0.4035
#
# Running Dataset:Tau_23: Epoch: 49: fileSet: 17
# Train on 48557 samples, validate on 12140 samples
# Epoch 1/1
# 48557/48557 [==============================] - 1s 26us/step - loss: 0.3067 - val_loss: 0.4065
#
# Running Dataset:Tau_23: Epoch: 49: fileSet: 3
# Train on 50346 samples, validate on 12587 samples
# Epoch 1/1
# 50346/50346 [==============================] - 1s 27us/step - loss: 0.3081 - val_loss: 0.3300
#
# Running Dataset:Tau_23: Epoch: 49: fileSet: 8
# Train on 50084 samples, validate on 12522 samples
# Epoch 1/1
# 50084/50084 [==============================] - 2s 32us/step - loss: 0.2972 - val_loss: 0.4403
#
# Running Dataset:Tau_23: Epoch: 49: fileSet: 19
# Train on 48320 samples, validate on 12080 samples
# Epoch 1/1
# 48320/48320 [==============================] - 1s 26us/step - loss: 0.3643 - val_loss: 0.4068
#
# Running Dataset:Tau_23: Epoch: 49: fileSet: 15
# Train on 48471 samples, validate on 12118 samples
# Epoch 1/1
# 48471/48471 [==============================] - 1s 26us/step - loss: 0.3093 - val_loss: 0.3832
#
# Running Dataset:Tau_23: Epoch: 49: fileSet: 10
# Train on 50375 samples, validate on 12594 samples
# Epoch 1/1
# 50375/50375 [==============================] - 1s 27us/step - loss: 0.3181 - val_loss: 0.4488
#
# Running Dataset:Tau_23: Epoch: 49: fileSet: 11
# Train on 48432 samples, validate on 12108 samples
# Epoch 1/1
# 48432/48432 [==============================] - 1s 26us/step - loss: 0.3142 - val_loss: 0.3927
#
# Running Dataset:Tau_23: Epoch: 49: fileSet: 20
# Train on 48560 samples, validate on 12141 samples
# Epoch 1/1
# 48560/48560 [==============================] - 1s 27us/step - loss: 0.3218 - val_loss: 0.4207
#
# Running Dataset:Tau_23: Epoch: 49: fileSet: 1
# Train on 50192 samples, validate on 12548 samples
# Epoch 1/1
# 50192/50192 [==============================] - 1s 26us/step - loss: 0.3053 - val_loss: 0.3550
# Saved model to disk
#
# Final Dataset Correlation: 0.9069
# CPU times: user 6h 20min 45s, sys: 4h 52min 40s, total: 11h 13min 26s
# Wall time: 3h 40min 6s

# %% [markdown]
# # 4. Make Predictions

# %%
os.chdir(path+"/Saved_Models_2Sets")
##### Load Model for tau_12
json_file = open('model2_Tau_12.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model_12 = model_from_json(loaded_model_json)

# load weights into new model
loaded_model_12.load_weights("model2_Tau_12.h5")
print("Loaded model 12 from disk")

# evaluate loaded model on test data 
# Define X_test & Y_test data first
loaded_model_12.compile(optimizer = tf.train.AdamOptimizer(), loss = "mse")

#### Load Model for tau_13
json_file = open('model2_Tau_13.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model_13 = model_from_json(loaded_model_json)

# load weights into new model
loaded_model_13.load_weights("model2_Tau_13.h5")
print("Loaded model 13 from disk")

# evaluate loaded model on test data 
# Define X_test & Y_test data first
loaded_model_13.compile(optimizer = tf.train.AdamOptimizer(), loss = "mse")

#### Load Model for tau_23
json_file = open('model2_Tau_23.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model_23 = model_from_json(loaded_model_json)

# load weights into new model
loaded_model_23.load_weights("model2_Tau_23.h5")
print("Loaded model 23 from disk")

# evaluate loaded model on test data 
# Define X_test & Y_test data first
loaded_model_23.compile(optimizer = tf.train.AdamOptimizer(), loss = "mse")
# Out:
# Loaded model 12 from disk
# Loaded model 13 from disk
# Loaded model 23 from disk

# %%
import math
from IPython.display import HTML, display
import tabulate
out = [["Data Source", "Result", "Tau_12", "Tau_13", "Tau_23"]]
dirs = [("Re15sh2_DNScoarse8",8),("Re15sh5_DNScoarse8",8),("Re15sh20_DNScoarse8",8)]
for (dataDir, coarse) in dirs:
    dirName = path + "/Data/" + dataDir
    os.chdir(dirName)
    print("Processing " + dirName)
    u = preprocess(scale(loadmat('u_F_xyz_T1_DNS'+str(coarse)+'.mat')["u_F"]))
    v = preprocess(scale(loadmat('v_F_xyz_T1_DNS'+str(coarse)+'.mat')["v_F"]))
    w = preprocess(scale(loadmat('w_F_xyz_T1_DNS'+str(coarse)+'.mat')["w_F"]))
    tau_12 = preprocess(scale(loadmat('tau12_F_xyz_T1_DNS'+str(coarse)+'.mat')["tau12"]))
    tau_13 = preprocess(scale(loadmat('tau13_F_xyz_T1_DNS'+str(coarse)+'.mat')["tau13"]))
    tau_23 = preprocess(scale(loadmat('tau23_F_xyz_T1_DNS'+str(coarse)+'.mat')["tau23"]))

    x = np.array([u, v, w])
    x = np.transpose(x, [1, 2, 3, 0])
    x = np.pad(x, ((3,3), (3,3), (3,3), (0,0)), 'constant', constant_values = 0)

    sample = []
    size = 3
    y_tau_12 = []
    y_tau_13 = []
    y_tau_23 = []
    for i in tqdm_notebook(range(size, x.shape[0] - size)):
        for j in range(size, x.shape[1] - size):
            for k in range(size, x.shape[2] - size):
                sample.append(x[i - size: i + size + 1, j - size: j + size + 1, k - size: k + size + 1, :])
                y_tau_12.append(tau_12[i - size][j - size][k - size])
                y_tau_13.append(tau_13[i - size][j - size][k - size])
                y_tau_23.append(tau_23[i - size][j - size][k - size])
            
    x = np.array(sample)
    y_tau_12 = np.array(y_tau_12)
    y_tau_13 = np.array(y_tau_13)
    y_tau_23 = np.array(y_tau_23)
    
    
    print("predicting tau_12")
    y_pred_12 = loaded_model_12.predict(x).flatten()


    print("predicting tau_13")
    y_pred_13 = loaded_model_13.predict(x).flatten()


    print("predicting tau_23")
    y_pred_23 = loaded_model_23.predict(x).flatten()

    out.append([dataDir, 'Corr', str(np.round(np.corrcoef(y_pred_12, y_tau_12)[0, 1], 4)), str(np.round(np.corrcoef(y_pred_13, y_tau_13)[0, 1], 4)), str(np.round(np.corrcoef(y_pred_23, y_tau_23)[0, 1], 4))])
    out.append(['', 'R^2', str(np.round(r2_score(y_tau_12, y_pred_12), 4)), str(np.round(r2_score(y_tau_13, y_pred_13), 4)), str(np.round(r2_score(y_tau_23, y_pred_23), 4))])
    
display(HTML(tabulate.tabulate(out, tablefmt = 'html')))
# Out:
# Processing /home/llin2948/dscaptstone/Data/Re15sh2_DNScoarse8
# HBox(children=(IntProgress(value=0, max=146), HTML(value='')))
# predicting tau_12
# predicting tau_13
# predicting tau_23
# Processing /home/llin2948/dscaptstone/Data/Re15sh5_DNScoarse8
# HBox(children=(IntProgress(value=0, max=146), HTML(value='')))
# predicting tau_12
# predicting tau_13
# predicting tau_23
# Processing /home/llin2948/dscaptstone/Data/Re15sh20_DNScoarse8
# HBox(children=(IntProgress(value=0, max=146), HTML(value='')))
# predicting tau_12
# predicting tau_13
# predicting tau_23
# <table>
# <tbody>
# <tr><td>Data Source        </td><td>Result</td><td>Tau_12</td><td>Tau_13</td><td>Tau_23</td></tr>
# <tr><td>Re15sh2_DNScoarse8 </td><td>Corr  </td><td>0.8409</td><td>0.8762</td><td>0.8892</td></tr>
# <tr><td>                   </td><td>R^2   </td><td>0.6503</td><td>0.7483</td><td>0.7742</td></tr>
# <tr><td>Re15sh5_DNScoarse8 </td><td>Corr  </td><td>0.8186</td><td>0.8493</td><td>0.8664</td></tr>
# <tr><td>                   </td><td>R^2   </td><td>0.6054</td><td>0.7013</td><td>0.7251</td></tr>
# <tr><td>Re15sh20_DNScoarse8</td><td>Corr  </td><td>0.8576</td><td>0.9017</td><td>0.8877</td></tr>
# <tr><td>                   </td><td>R^2   </td><td>0.5483</td><td>0.7534</td><td>0.7339</td></tr>
# </tbody>
# </table>
