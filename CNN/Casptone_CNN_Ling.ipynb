# %%
# %%capture
import tensorflow as tf
from tensorflow import keras
from scipy.io import loadmat
from tensorflow.keras import regularizers
import os
import time
import numpy as np
import gc
import zipfile
from tensorflow.keras.models import model_from_json
import tqdm
import h5py
from tqdm import tqdm_notebook
import matplotlib.pyplot as plt
from tensorflow.keras import backend as K
from sklearn.metrics import r2_score
from sklearn import preprocessing

# %%
def scale(x):

    return (x - np.mean(x)) / np.std(x)

# %%
def preprocess(x):
    
    return x[:,:,:int(0.75*75)]#x.shape[2])]

# %%
def cut(x, switch):
    temp = []
    size = int(x.shape[0] / 5)
    for i in range(5):
        temp.append(x[i * size:(i + 1) * size])
    x = np.array(temp)
    
    if switch:
        x = np.reshape(x, (5,-1))
    
    return x

# %%
os.chdir("../Data/Re15sh20_DNScoarse8")
u = preprocess(scale(loadmat('u_F_xyz_T1.mat')["u_F"]))
v = preprocess(scale(loadmat('v_F_xyz_T1.mat')["v_F"]))
w = preprocess(scale(loadmat('w_F_xyz_T1.mat')["w_F"]))
tau_12 = preprocess(scale(loadmat('tau12_xyz_T1.mat')["tau12"]))
tau_13 = preprocess(scale(loadmat('tau13_xyz_T1.mat')["tau13"]))
tau_23 = preprocess(scale(loadmat('tau23_xyz_T1.mat')["tau23"]))

# %%
all_taus = False
significance = True

# %% [markdown]
# ### Create Datasets

# %%
x = np.array([u, v, w])
#tke, theta])
x = np.transpose(x, [1, 2, 3, 0])
#x = np.reshape(x, (1, x.shape[0], x.shape[1], x.shape[2], x.shape[3]))
print(x.shape)
x = cut(x, False)
print(x.shape)
# Out:
# (146, 96, 56, 3)
# (5, 29, 96, 56, 3)

# %%
tau_12 = cut(tau_12, False)#np.reshape(tau_12, (1, -1))
print(tau_12.shape)
tau_13 = cut(tau_13, False)#np.reshape(tau_13, (1, -1))
print(tau_12.shape)
tau_23 = cut(tau_23, False)#np.reshape(tau_23, (1, -1))
print(tau_23.shape)
# Out:
# (5, 29, 96, 56)
# (5, 29, 96, 56)
# (5, 29, 96, 56)

# %% [markdown]
# ### Create Model Class

# %%
class CNN(object):
    
    def __init__(self, activation, initializer, regularizer, x_train, y_train, epochs, batch_size, input_shape, filter_size, val_split, x_val, y_val):
        self.activation = activation
        self.initializer = initializer
        self.regularizer = regularizer
        self.x_train = x_train
        self.y_train = y_train
        self.epochs = epochs
        self.batch_size = batch_size
        self.input_shape = input_shape
        self.filter = filter_size
        self.val_split = val_split
        self.x_val = x_val
        self.y_val = y_val
        
        pass         
    
    def create_model(self):    
        model = keras.Sequential([
            tf.keras.layers.Conv3D(128,
                             kernel_size = self.filter,
                             activation = self.activation,
                             input_shape = input_shape,   
                             padding = "same",
                             kernel_regularizer = self.regularizer,
                             data_format = 'channels_last'),
            tf.keras.layers.AveragePooling3D(pool_size = (29,96,56)),
            tf.keras.layers.Flatten(),
            tf.keras.layers.Dense(64, 
                             activation = self.activation, 
                             kernel_regularizer = self.regularizer, 
                             kernel_initializer = self.initializer),
            tf.keras.layers.Dropout(0.2),
            tf.keras.layers.Dense(32, 
                             activation = self.activation, 
                             kernel_regularizer = self.regularizer, 
                             kernel_initializer = self.initializer),
            tf.keras.layers.Dropout(0.2),
            tf.keras.layers.Dense(self.y_train.shape[1])
        ])
        
        return model
    
    def callbacks(self):
        early_stopping = tf.keras.callbacks.EarlyStopping(monitor = 'val_loss',
                                               min_delta = 0.001,
                                               patience = 0,
                                               verbose = 0)
        
        return early_stopping
    
    def run_model(self):
        model = self.create_model()
        model.compile(optimizer = tf.train.AdamOptimizer(), 
              loss = "mse")
        model.summary()
            
        history = model.fit(self.x_train, self.y_train, 
                    epochs = self.epochs, 
                    #validation_split = self.val_split, 
                    validation_data = (self.x_val, self.y_val),
                    batch_size =  self.batch_size,
                    verbose = 1)
                    #callbacks = [self.callbacks()])
        
        return history, model

# %% [markdown]
# ###  Compare TKE, $\theta$ and Base

# %%
if significance:
    activation = tf.nn.relu
    initializer = None
    regularizer = None
    epochs = 50
    batch_size = 1
    filter_size = (7,7,7)
    val_split = 0.0

    fig = plt.figure(figsize = (20, 6))
    results = {}
    i = 1
    x_train, x_val = x[1:], x[0]
    x_val = x_val.reshape((1, x_val.shape[0], x_val.shape[1], x_val.shape[2], x_val.shape[3]))
    
    y_datasets = [tau_12, tau_13, tau_23]
    for y_dataset in y_datasets:
        y_train, y_val = y_dataset[1:], y_dataset[0]
        y_train = y_train.reshape((4, -1))
        y_val = y_val.reshape((1, -1))

        input_shape = (x_train.shape[1], x_train.shape[2], x_train.shape[3], x_train.shape[4])
        model = CNN(activation, initializer, regularizer, x_train, y_train, epochs, batch_size, input_shape, filter_size, val_split, x_val, y_val)
        history, model = model.run_model()

        fig.add_subplot(1, 3, i)
        plt.plot(history.epoch, np.array(history.history['loss']), label = 'Train Loss')
        plt.plot(history.epoch, np.array(history.history['val_loss']), label = 'Val Loss')
        plt.xlabel('Epoch')
        plt.ylabel('Mean Square Error')
        plt.legend()

        y_pred = model.predict(x_train).flatten()
        y_true = y_train.flatten()
        print("R^2: %.4f" % r2_score(y_true, y_pred))
        print("Correlation: %.4f\n" % np.corrcoef(y_pred, y_true)[0, 1])
        results[np.corrcoef(y_pred, y_true)[0, 1]] = x
        
        del y_train
        del y_val
        del model
        del y_pred
        del y_true
        gc.collect()
        i = i + 1
        
    plt.show()
    
    del x_train
    del x_val
    gc.collect()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d (Conv3D)              (None, 29, 96, 56, 128)   131840
# _________________________________________________________________
# average_pooling3d (AveragePo (None, 1, 1, 1, 128)      0
# _________________________________________________________________
# flatten (Flatten)            (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 64)                8256
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 155904)            5144832
# =================================================================
# Total params: 5,287,008
# Trainable params: 5,287,008
# Non-trainable params: 0
# _________________________________________________________________
# Train on 4 samples, validate on 1 samples
# Epoch 1/50
# 4/4 [==============================] - 7s 2s/step - loss: 1.3315 - val_loss: 1.3534
# Epoch 2/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.3253 - val_loss: 1.3532
# Epoch 3/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.2959 - val_loss: 1.3565
# Epoch 4/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.2300 - val_loss: 1.3819
# Epoch 5/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.1628 - val_loss: 1.4652
# Epoch 6/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.1395 - val_loss: 1.5792
# Epoch 7/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.0889 - val_loss: 1.6092
# Epoch 8/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.1034 - val_loss: 1.5511
# Epoch 9/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.0475 - val_loss: 1.5166
# Epoch 10/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.0532 - val_loss: 1.5143
# Epoch 11/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.0714 - val_loss: 1.5673
# Epoch 12/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.0628 - val_loss: 1.6235
# Epoch 13/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.0908 - val_loss: 1.6397
# Epoch 14/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.0722 - val_loss: 1.5608
# Epoch 15/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.0981 - val_loss: 1.5198
# Epoch 16/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.0737 - val_loss: 1.5051
# Epoch 17/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.0612 - val_loss: 1.5102
# Epoch 18/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.0708 - val_loss: 1.5463
# Epoch 19/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.0740 - val_loss: 1.5856
# Epoch 20/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.0085 - val_loss: 1.6239
# Epoch 21/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.0891 - val_loss: 1.6137
# Epoch 22/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.0238 - val_loss: 1.5688
# Epoch 23/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.0879 - val_loss: 1.5564
# Epoch 24/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.0115 - val_loss: 1.5626
# Epoch 25/50
# 4/4 [==============================] - 5s 1s/step - loss: 0.9847 - val_loss: 1.5813
# Epoch 26/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.0355 - val_loss: 1.6031
# Epoch 27/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.0679 - val_loss: 1.5784
# Epoch 28/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.0250 - val_loss: 1.5361
# Epoch 29/50
# 4/4 [==============================] - 6s 1s/step - loss: 1.0419 - val_loss: 1.5435
# Epoch 30/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.0673 - val_loss: 1.5752
# Epoch 31/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.0062 - val_loss: 1.6280
# Epoch 32/50
# 4/4 [==============================] - 5s 1s/step - loss: 0.9898 - val_loss: 1.6475
# Epoch 33/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.0590 - val_loss: 1.6568
# Epoch 34/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.0215 - val_loss: 1.6152
# Epoch 35/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.0286 - val_loss: 1.5637
# Epoch 36/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.0328 - val_loss: 1.5551
# Epoch 37/50
# 4/4 [==============================] - 6s 1s/step - loss: 0.9717 - val_loss: 1.5861
# Epoch 38/50
# 4/4 [==============================] - 6s 1s/step - loss: 1.1157 - val_loss: 1.6002
# Epoch 39/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.0700 - val_loss: 1.5998
# Epoch 40/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.0817 - val_loss: 1.6177
# Epoch 41/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.0708 - val_loss: 1.6390
# Epoch 42/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.0749 - val_loss: 1.6491
# Epoch 43/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.1210 - val_loss: 1.6213
# Epoch 44/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.0984 - val_loss: 1.5731
# Epoch 45/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.0349 - val_loss: 1.5552
# Epoch 46/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.0060 - val_loss: 1.5790
# Epoch 47/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.0715 - val_loss: 1.5842
# Epoch 48/50
# 4/4 [==============================] - 5s 1s/step - loss: 0.9841 - val_loss: 1.6001
# Epoch 49/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.0589 - val_loss: 1.6127
# Epoch 50/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.0431 - val_loss: 1.6383
# R^2: 0.2470
# Correlation: 0.4971
#
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_1 (Conv3D)            (None, 29, 96, 56, 128)   131840
# _________________________________________________________________
# average_pooling3d_1 (Average (None, 1, 1, 1, 128)      0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 155904)            5144832
# =================================================================
# Total params: 5,287,008
# Trainable params: 5,287,008
# Non-trainable params: 0
# _________________________________________________________________
# Train on 4 samples, validate on 1 samples
# Epoch 1/50
# 4/4 [==============================] - 6s 2s/step - loss: 1.2878 - val_loss: 1.4146
# Epoch 2/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.2474 - val_loss: 1.3846
# Epoch 3/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.1600 - val_loss: 1.3719
# Epoch 4/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.0722 - val_loss: 1.3989
# Epoch 5/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.0054 - val_loss: 1.4142
# Epoch 6/50
# 4/4 [==============================] - 5s 1s/step - loss: 0.9433 - val_loss: 1.4195
# Epoch 7/50
# 4/4 [==============================] - 5s 1s/step - loss: 0.9764 - val_loss: 1.3887
# Epoch 8/50
# 4/4 [==============================] - 5s 1s/step - loss: 0.9097 - val_loss: 1.3861
# Epoch 9/50
# 4/4 [==============================] - 5s 1s/step - loss: 0.8727 - val_loss: 1.3846
# Epoch 10/50
# 4/4 [==============================] - 5s 1s/step - loss: 0.9195 - val_loss: 1.4185
# Epoch 11/50
# 4/4 [==============================] - 5s 1s/step - loss: 0.8838 - val_loss: 1.4310
# Epoch 12/50
# 4/4 [==============================] - 5s 1s/step - loss: 0.8786 - val_loss: 1.4082
# Epoch 13/50
# 4/4 [==============================] - 5s 1s/step - loss: 0.8869 - val_loss: 1.3891
# Epoch 14/50
# 4/4 [==============================] - 5s 1s/step - loss: 0.8973 - val_loss: 1.3846
# Epoch 15/50
# 4/4 [==============================] - 5s 1s/step - loss: 0.9104 - val_loss: 1.3899
# Epoch 16/50
# 4/4 [==============================] - 5s 1s/step - loss: 0.8700 - val_loss: 1.3940
# Epoch 17/50
# 4/4 [==============================] - 5s 1s/step - loss: 0.8649 - val_loss: 1.4296
# Epoch 18/50
# 4/4 [==============================] - 5s 1s/step - loss: 0.8621 - val_loss: 1.4662
# Epoch 19/50
# 4/4 [==============================] - 5s 1s/step - loss: 0.8614 - val_loss: 1.4849
# Epoch 20/50
# 4/4 [==============================] - 5s 1s/step - loss: 0.8779 - val_loss: 1.5089
# Epoch 21/50
# 4/4 [==============================] - 5s 1s/step - loss: 0.9279 - val_loss: 1.4634
# Epoch 22/50
# 4/4 [==============================] - 5s 1s/step - loss: 0.9148 - val_loss: 1.4277
# Epoch 23/50
# 4/4 [==============================] - 5s 1s/step - loss: 0.8608 - val_loss: 1.4057
# Epoch 24/50
# 4/4 [==============================] - 5s 1s/step - loss: 0.9431 - val_loss: 1.3989
# Epoch 25/50
# 4/4 [==============================] - 5s 1s/step - loss: 0.8822 - val_loss: 1.4130
# Epoch 26/50
# 4/4 [==============================] - 5s 1s/step - loss: 0.8329 - val_loss: 1.4346
# Epoch 27/50
# 4/4 [==============================] - 5s 1s/step - loss: 0.8675 - val_loss: 1.4282
# Epoch 28/50
# 4/4 [==============================] - 5s 1s/step - loss: 0.8497 - val_loss: 1.4106
# Epoch 29/50
# 4/4 [==============================] - 5s 1s/step - loss: 0.9234 - val_loss: 1.3841
# Epoch 30/50
# 4/4 [==============================] - 5s 1s/step - loss: 0.8633 - val_loss: 1.3693
# Epoch 31/50
# 4/4 [==============================] - 5s 1s/step - loss: 0.8583 - val_loss: 1.3943
# Epoch 32/50
# 4/4 [==============================] - 5s 1s/step - loss: 0.8279 - val_loss: 1.4466
# Epoch 33/50
# 4/4 [==============================] - 5s 1s/step - loss: 0.9503 - val_loss: 1.4611
# Epoch 34/50
# 4/4 [==============================] - 5s 1s/step - loss: 0.8924 - val_loss: 1.4184
# Epoch 35/50
# 4/4 [==============================] - 5s 1s/step - loss: 0.8417 - val_loss: 1.3836
# Epoch 36/50
# 4/4 [==============================] - 5s 1s/step - loss: 0.8647 - val_loss: 1.3774
# Epoch 37/50
# 4/4 [==============================] - 5s 1s/step - loss: 0.8457 - val_loss: 1.4018
# Epoch 38/50
# 4/4 [==============================] - 5s 1s/step - loss: 0.8599 - val_loss: 1.4346
# Epoch 39/50
# 4/4 [==============================] - 5s 1s/step - loss: 0.9305 - val_loss: 1.4635
# Epoch 40/50
# 4/4 [==============================] - 5s 1s/step - loss: 0.8968 - val_loss: 1.4507
# Epoch 41/50
# 4/4 [==============================] - 5s 1s/step - loss: 0.8793 - val_loss: 1.4129
# Epoch 42/50
# 4/4 [==============================] - 5s 1s/step - loss: 0.8842 - val_loss: 1.3909
# Epoch 43/50
# 4/4 [==============================] - 5s 1s/step - loss: 0.8606 - val_loss: 1.3824
# Epoch 44/50
# 4/4 [==============================] - 5s 1s/step - loss: 0.8839 - val_loss: 1.3991
# Epoch 45/50
# 4/4 [==============================] - 5s 1s/step - loss: 0.8512 - val_loss: 1.3989
# Epoch 46/50
# 4/4 [==============================] - 5s 1s/step - loss: 0.8948 - val_loss: 1.4037
# Epoch 47/50
# 4/4 [==============================] - 5s 1s/step - loss: 0.9033 - val_loss: 1.4150
# Epoch 48/50
# 4/4 [==============================] - 5s 1s/step - loss: 0.8982 - val_loss: 1.4227
# Epoch 49/50
# 4/4 [==============================] - 5s 1s/step - loss: 0.8462 - val_loss: 1.4518
# Epoch 50/50
# 4/4 [==============================] - 5s 1s/step - loss: 0.8837 - val_loss: 1.4971
# R^2: 0.3394
# Correlation: 0.5853
#
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_2 (Conv3D)            (None, 29, 96, 56, 128)   131840
# _________________________________________________________________
# average_pooling3d_2 (Average (None, 1, 1, 1, 128)      0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_7 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_8 (Dense)              (None, 155904)            5144832
# =================================================================
# Total params: 5,287,008
# Trainable params: 5,287,008
# Non-trainable params: 0
# _________________________________________________________________
# Train on 4 samples, validate on 1 samples
# Epoch 1/50
# 4/4 [==============================] - 6s 2s/step - loss: 1.3275 - val_loss: 1.3749
# Epoch 2/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.3226 - val_loss: 1.3739
# Epoch 3/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.2908 - val_loss: 1.3757
# Epoch 4/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.2336 - val_loss: 1.3997
# Epoch 5/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.1449 - val_loss: 1.4849
# Epoch 6/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.1379 - val_loss: 1.6166
# Epoch 7/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.0955 - val_loss: 1.5736
# Epoch 8/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.0666 - val_loss: 1.5115
# Epoch 9/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.0617 - val_loss: 1.5189
# Epoch 10/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.0412 - val_loss: 1.5836
# Epoch 11/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.0298 - val_loss: 1.6044
# Epoch 12/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.0725 - val_loss: 1.5709
# Epoch 13/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.0306 - val_loss: 1.5684
# Epoch 14/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.0419 - val_loss: 1.5739
# Epoch 15/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.0044 - val_loss: 1.5665
# Epoch 16/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.0192 - val_loss: 1.5805
# Epoch 17/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.0433 - val_loss: 1.5681
# Epoch 18/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.0051 - val_loss: 1.5724
# Epoch 19/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.0570 - val_loss: 1.5815
# Epoch 20/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.0216 - val_loss: 1.6373
# Epoch 21/50
# 4/4 [==============================] - 5s 1s/step - loss: 0.9666 - val_loss: 1.7521
# Epoch 22/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.0793 - val_loss: 1.7563
# Epoch 23/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.0363 - val_loss: 1.6293
# Epoch 24/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.0599 - val_loss: 1.5351
# Epoch 25/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.0225 - val_loss: 1.5030
# Epoch 26/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.0464 - val_loss: 1.5172
# Epoch 27/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.0408 - val_loss: 1.5752
# Epoch 28/50
# 4/4 [==============================] - 5s 1s/step - loss: 0.9761 - val_loss: 1.6385
# Epoch 29/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.0211 - val_loss: 1.6400
# Epoch 30/50
# 4/4 [==============================] - 5s 1s/step - loss: 0.9794 - val_loss: 1.5985
# Epoch 31/50
# 4/4 [==============================] - 5s 1s/step - loss: 0.9765 - val_loss: 1.5955
# Epoch 32/50
# 4/4 [==============================] - 5s 1s/step - loss: 0.9790 - val_loss: 1.6179
# Epoch 33/50
# 4/4 [==============================] - 5s 1s/step - loss: 0.9922 - val_loss: 1.6412
# Epoch 34/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.0369 - val_loss: 1.6489
# Epoch 35/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.0296 - val_loss: 1.6319
# Epoch 36/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.0709 - val_loss: 1.6220
# Epoch 37/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.1482 - val_loss: 1.5869
# Epoch 38/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.0179 - val_loss: 1.5259
# Epoch 39/50
# 4/4 [==============================] - 5s 1s/step - loss: 0.9814 - val_loss: 1.5181
# Epoch 40/50
# 4/4 [==============================] - 5s 1s/step - loss: 0.9927 - val_loss: 1.5603
# Epoch 41/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.1020 - val_loss: 1.6371
# Epoch 42/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.0650 - val_loss: 1.7009
# Epoch 43/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.0643 - val_loss: 1.6259
# Epoch 44/50
# 4/4 [==============================] - 5s 1s/step - loss: 0.9877 - val_loss: 1.5743
# Epoch 45/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.0374 - val_loss: 1.5506
# Epoch 46/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.0752 - val_loss: 1.5543
# Epoch 47/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.0177 - val_loss: 1.5577
# Epoch 48/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.0361 - val_loss: 1.5511
# Epoch 49/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.0892 - val_loss: 1.5408
# Epoch 50/50
# 4/4 [==============================] - 5s 1s/step - loss: 1.0150 - val_loss: 1.5411
# R^2: 0.2427
# Correlation: 0.5022
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-b159cefa646e> in <module>
#      53     del x_train
#      54     del x_val
# ---> 55     del datasets
#      56     gc.collect()
#
# NameError: name 'datasets' is not defined
